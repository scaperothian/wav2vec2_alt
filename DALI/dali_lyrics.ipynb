# %% [markdown]
# # DALI Sandbox
#
# Exercise pulling out metadata from DALI on version 1 and version 2.  Below I pull out artist lyrics for Taylor Swift and Muse and save transcripts in a local directory transcripts/artist_name/song_id.txt

# %%
import os
import json
import sys

import tqdm
import numpy as np
import pandas as pd

import DALI as dali_code
from DALI import utilities

# %%
# import DALI data
dali_version = 1 #2

dali_data_path = os.getcwd()+'/'+f"metadata_v{str(dali_version)}"
dali_data = dali_code.get_the_DALI_dataset(dali_data_path, skip=[], keep=[])

# %%
if dali_version == 1:
    dali_info = dali_code.get_info(dali_data_path + '/info/DALI_DATA_INFO.gz')
    entry = dali_data['0091064bdc72469ca7096d3a0db74562']
    print(json.dumps(entry.info,indent=2))
elif dali_version == 2: 
    entry = dali_data['fff64f1669c34253928802a9ed246d2f']
    print(json.dumps(entry.info,indent=2))
# Out:
# {
#   "dataset_version": 1.0,
#   "ground-truth": false,
#   "artist": "Five For Fighting",
#   "title": "100 Years",
#   "scores": {
#     "NCC": 0.8314642198566967,
#     "manual": 0.0
#   },
#   "audio": {
#     "url": "fJN9YIOl1xE",
#     "path": "None",
#     "working": true
#   },
#   "id": "0091064bdc72469ca7096d3a0db74562",
#   "metadata": {
#     "album": "The Battle for Everything",
#     "release_date": "2004",
#     "cover": "https://e-cdns-images.dzcdn.net/images/cover/a9da82ee07fc50da6052e27e9c97e6cd/1000x1000-000000-80-0-0.jpg",
#     "genres": [
#       "Rock"
#     ],
#     "language": "english"
#   }
# }

# %% [markdown]
# # Parse the lyrics from a single song

# %%
display(entry.info['metadata'])
display(entry.info['audio'])
display(entry.info['artist'])
display(entry.info['ground-truth'])
# Out:
# {'album': 'The Battle for Everything',
#  'release_date': '2004',
#  'cover': 'https://e-cdns-images.dzcdn.net/images/cover/a9da82ee07fc50da6052e27e9c97e6cd/1000x1000-000000-80-0-0.jpg',
#  'genres': ['Rock'],
#  'language': 'english'}
# {'url': 'fJN9YIOl1xE', 'path': 'None', 'working': True}
# 'Five For Fighting'
# False

# %%
lyrics = [v for d in entry.annotations['annot']['lines'] for k,v in d.items() if k=="text"]
' '.join(lyrics)
# Out:
# "i'm fifteen for a moment caught in between ten and twenty and i'm just dreaming counting the ways to where you are i'm twenty two for a moment and she feels better than ever and we're on fire making our way back from mars fifteen there's still time for you time to buy and time to lose fifteen, there's never a wish better than this when you only got a hundred years to live i'm thirty three for a moment but still the man, but you see i'm of age kid on the way babe a family on my mind i'm forty five for a moment the sea is high and i'm heading into a crisis chasing the years of my life fifteen there's still time for you time to buy and time to lose yourself within a morning star fif teen i'm all right with you fifteen, nev-er a wish better than-this when you onlygot a hundredyears to live half timegoes by suddenly you're wise- another blink of aneye sixty seven isgone the sun isget ting high we're moving on i'mnine ty nine for a moment timefor just anothermo ment and i'm just dreaming counting the ways to where you are fif teen there's still time for you- twenty two i feel her too thirty three you'reon your way- ev eryday's anew day wooooo wooooo wooooo o fifteen there'sstill timefor you- time to buy andtime-tochoose hey- fifteen,there's never a wish better than this when you only got a hundrd years to live"

# %%
lyrics2 = [v for d in entry.annotations['annot']['paragraphs'] for k,v in d.items() if k=="text"]
'\n\n'.join(lyrics2)
# Out:
# "i'm fifteen for a moment caught in between ten and twenty and i'm just dreaming counting the ways to where you are\n\ni'm twenty two for a moment and she feels better than ever and we're on fire making our way back from mars\n\nfifteen there's still time for you time to buy and time to lose fifteen, there's never a wish better than this when you only got a hundred years to live\n\ni'm thirty three for a moment but still the man, but you see i'm of age kid on the way babe a family on my mind\n\ni'm forty five for a moment the sea is high and i'm heading into a crisis chasing the years of my life\n\nfifteen there's still time for you time to buy and time to lose yourself within a morning star\n\nfif teen i'm all right with you fifteen, nev-er a wish better than-this when you onlygot a hundredyears to live\n\nhalf timegoes by suddenly you're wise- another blink of aneye sixty seven isgone the sun isget ting high we're moving on\n\ni'mnine ty nine for a moment timefor just anothermo ment and i'm just dreaming counting the ways to where you are\n\nfif teen there's still time for you- twenty two i feel her too thirty three you'reon your way- ev eryday's anew day\n\nwooooo wooooo wooooo o fifteen there'sstill timefor you- time to buy andtime-tochoose hey- fifteen,there's never a wish better than this when you only got a hundrd years to live"

# %% [markdown]
# # Find short utterances that would fit with wav2vec2 anlysis.

# %%
# finds utterances...
def find_utterances(dali_entry):
    """
    find all utterances in a single DALI "entry" or song.  
    save and return the metadata in a dictionary.

    note: only save utterances that are longer than 1.0s or shorter
          than 28 seconds.

    file_id: uuid that aligns with the audio song base filename
    utt_id: unique id for that song utterance 
    start_time: start time in seconds of utterance
    stop_time: stop time in seconds of utterance
    duration: duratio of utterance in seconds
    text: transcript of snippet
    
    dali_entry: structure for accessing metadata for dali songs.
    """
    j = 0
    arr = []
    for i, d in enumerate(dali_entry.annotations['annot']['lines']):
        
        # fetch metadata for a line
        for k,v in d.items():

            
            if k=='time':
                # calculate duration when the key is time.
                duration = v[1]-v[0]

                # only keep utterances that fit the criteria.
                if (1.0 < duration < 28.0):
                    
                    j += 1
    
                    # save the metadata
                    arr.append({'file_id':entry.info['id'], 'utt_id':i, 'start_time':v[0], 'stop_time':v[1], 'duration':duration, 'text':d['text']})
    return arr

utt_array = find_utterances(entry)
print(f"{len(utt_array)} lines fit criteria out of {len(entry.annotations['annot']['lines'])}")
# Out:
# 47 lines fit criteria out of 47

# %% [markdown]
# # Creating Single Song Utterances from DALI

# %%
from IPython.display import Audio
import torchaudio

# for song_utt in utt_array:
song_utt = utt_array[1]
# this finds the file, parses the file, then plays the snippet.
filename = f"dali_datasets/test/{entry.info['id']}.wav"
if os.path.isfile(filename):
    wav, sr = torchaudio.load(filename)
else:
    print(f"File: {filename} does not exist.")

start_samp = int(song_utt['start_time'] * sr)
stop_samp = int(song_utt['stop_time'] * sr)
print(song_utt['text'])
Audio(wav[0,start_samp:stop_samp],rate=sr)
# Out:
# caught in between ten and twenty and i'm
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Automation of the cell above for a single entry...

def create_file_name(fileid,linenum):
    return f"{fileid}_{linenum}.wav"

def create_metadata_file(utt_array, destination_dir="./",create_csv=False):
    """
    create_metadata_file - create metadata file for HuggingFace DataSet from array of utterances

    utt_array - list of dictionary objects.  each object is dictionary is generated by find_utterances

    returns dataframe used to create the csv.
    """
    # 
    #
    # creating transcript column
    transcripts = [song_utt['text'].upper() for song_utt in utt_array]
    # creating filenames column.
    file_names  = [create_file_name(song_utt['file_id'],song_utt['utt_id']) for song_utt in utt_array]
    #convert to dataframe
    metadata_df = pd.DataFrame({'file_name':file_names, 'transcription':transcripts})
    
    # save as csv
    if create_csv:
        print("create_metadata_file: Saving to CSV...")
        metadata_df.to_csv(f"{destination_dir}/metadata.csv",index=False)

    return metadata_df

def create_utt_files(utt_array, audio_dir, destination_dir=None):

    if destination_dir is None:
        destination_dir=audio_dir

    print(f"Saving Files from: {utt_array[0]['file_id']}")

    # iterate through all utterances 
    for song_utt in utt_array:
        
        # this finds the file, parses the file
        filename = f"{audio_dir}/{entry.info['id']}.wav"
        if os.path.isfile(filename):
            wav, sr = torchaudio.load(filename)
        else:
            # this is ok because we are trying to make utterance files
            # from a metadata file where some files may or may not be 
            # downloaded.  so the user is warned, but we obstensively 
            # give up and let the user figure out how to get that file
            # or just be happy without that file.
            print(f"File: {filename} does not exist....moving on.")
            return False

        start_samp = int(song_utt['start_time'] * sr)
        stop_samp = int(song_utt['stop_time'] * sr)
        
        # crop and shape the waveform based on 
        newwav = wav[0,start_samp:stop_samp]
        newwav = newwav.reshape((1,-1))
        newwav_filename = create_file_name(song_utt['file_id'], song_utt['utt_id'])
        newwav_transcript = song_utt['text']
    
        # saving utterance...
        torchaudio.save(f"{destination_dir}/{newwav_filename}",newwav,sample_rate=sr)
    
    return True

def create_utt_corpus_from_entry(dali_entry, audio_dir, destination_dir=None):
    """
    
    Creating audio snippets and a metadata file that will 
    go in the audio_dir to support importing the song 
    into Huggingface Dataset object.  

    destination_dir - location where the audio and metadata will be stored.
                      if None, then use audio_dir.
    
    """

    # find all utterances using the DALI metadata labels 
    # utt_array is a dictionary with file, duration, and transcript 
    # details.  see method.
    utt_array = find_utterances(dali_entry)

    # Using the utt_array, we generation files (wav files) 
    # assuming the source audio is in the directory 
    # audio_dir.  Destination_dir is where utterance files
    # will be stored.
    #
    # Returns False if File not found in audio_dir.
    file_found = create_utt_files(utt_array, audio_dir, destination_dir)

    if file_found:
        # Once the audio is created, we need to create the audio 
        # metadata file.  This file will be stored in destination_dir
        #print(f"create_metadata_file: {len(utt_array)}, {destination_dir}")
        return create_metadata_file(utt_array, destination_dir)
        
    return False

# %%
audio_dir = "dali_datasets/test"
destination_dir = "dali_datasets/newtest"

md_df = create_utt_corpus_from_entry(entry, audio_dir, destination_dir)
# Out:
# Saving Files from: b1b6bc336f78441b8b31da555ccf59d8
# File: dali_datasets/test/b1b6bc336f78441b8b31da555ccf59d8.wav does not exist....moving on.

# %% [markdown]
# # Find all Entries in DALI Test Metadata

# %%
# import the dali_test metadata...
dali_test_metadata_df = pd.read_csv("DALI_TestSet4ALT.csv")          
dali_ids = [dali_id for dali_id in dali_test_metadata_df['DALI_ID']]

# %%
audio_dir = "dali_datasets/test"
destination_dir = "dali_datasets/newtest"

final_metadata_df = pd.DataFrame({"file_name":[],"transcription":[]})

for i, dali_id in enumerate(dali_ids):
    entry = dali_data[dali_id]
    df_temp = create_utt_corpus_from_entry(entry, audio_dir, destination_dir)

    if isinstance(df_temp,pd.DataFrame): 
        print(f"{i}: creating dataframe for {entry.info['id']}") 
        final_metadata_df = pd.concat([final_metadata_df, df_temp], ignore_index=True, sort=False)
    else:
        print(f"Skip: {entry.info['id']}")
# Out:
# Saving Files from: 44a2455abc0e4fb397a396d2cd1ebeb9
# 0: creating dataframe for 44a2455abc0e4fb397a396d2cd1ebeb9
# Saving Files from: 15d6e9e88ced41dfbff38ba2f3e1d885
# 1: creating dataframe for 15d6e9e88ced41dfbff38ba2f3e1d885
# Saving Files from: a59e44a4c910443a87f068b177200fdc
# 2: creating dataframe for a59e44a4c910443a87f068b177200fdc
# Saving Files from: ae91bcda73944695b7756ddc066c3e02
# 3: creating dataframe for ae91bcda73944695b7756ddc066c3e02
# Saving Files from: d6e3cf403653490f8366bf77cbc0f186
# 4: creating dataframe for d6e3cf403653490f8366bf77cbc0f186
# Saving Files from: 7a1642003f574713a6e25e5ee549fce6
# 5: creating dataframe for 7a1642003f574713a6e25e5ee549fce6
# Saving Files from: 8eb15ad6d17f41b68009fe3848930dee
# 6: creating dataframe for 8eb15ad6d17f41b68009fe3848930dee
# Saving Files from: b63d71b7ec6b4c5e9f53a87f83fcd73e
# 7: creating dataframe for b63d71b7ec6b4c5e9f53a87f83fcd73e
# Saving Files from: ac0279efad294261b4c7dc0b86eaaec5
# 8: creating dataframe for ac0279efad294261b4c7dc0b86eaaec5
# Saving Files from: 1478242633aa4628aa9a88ca6f54130a
# File: dali_datasets/test/1478242633aa4628aa9a88ca6f54130a.wav does not exist....moving on.
# Skip: 1478242633aa4628aa9a88ca6f54130a
# Saving Files from: b60f5426792642f9a9c59717d0ec3b23
# 10: creating dataframe for b60f5426792642f9a9c59717d0ec3b23
# Saving Files from: 5f8ea2abaad54d8e890fadcc7750710f
# 11: creating dataframe for 5f8ea2abaad54d8e890fadcc7750710f
# Saving Files from: 6f7e697152bf4c7f872752e5a12acdbf
# File: dali_datasets/test/6f7e697152bf4c7f872752e5a12acdbf.wav does not exist....moving on.
# Skip: 6f7e697152bf4c7f872752e5a12acdbf
# Saving Files from: 0ef5da404f744772adbcb789d3a2d9d9
# 13: creating dataframe for 0ef5da404f744772adbcb789d3a2d9d9
# Saving Files from: aa865cacc7d843ac9752ca368371e556
# File: dali_datasets/test/aa865cacc7d843ac9752ca368371e556.wav does not exist....moving on.
# Skip: aa865cacc7d843ac9752ca368371e556
# Saving Files from: 53e2da93b8a84468b6f1264055a18001
# 15: creating dataframe for 53e2da93b8a84468b6f1264055a18001
# Saving Files from: 0a1c2a896fa34688b86547f4317a7733
# 16: creating dataframe for 0a1c2a896fa34688b86547f4317a7733
# Saving Files from: 77f5ee6a6b3a49a294041627fe2f47c0
# 17: creating dataframe for 77f5ee6a6b3a49a294041627fe2f47c0
# Saving Files from: ef6eb0055c5d45e8a694a621c9cf3d87
# 18: creating dataframe for ef6eb0055c5d45e8a694a621c9cf3d87
# Saving Files from: 25276e977b304d15bd621dd63b291e15
# 19: creating dataframe for 25276e977b304d15bd621dd63b291e15
# Saving Files from: 5e774785ea79424d96974f5662332b31
# 66: creating dataframe for 134fa78a3d4a462299db018f0444ce26
# Saving Files from: 97349fc35f414864ab080f7c78e3f51e
# 67: creating dataframe for 97349fc35f414864ab080f7c78e3f51e
# Saving Files from: 647553dfb24b4f63832722217cbc1857
# 68: creating dataframe for 647553dfb24b4f63832722217cbc1857
# Saving Files from: 11a0f31e81094120bf8439c597b6c7d8
# 69: creating dataframe for 11a0f31e81094120bf8439c597b6c7d8
# Saving Files from: 74ba3bdc8c2f422a9e986a0522b0e6c5
# File: dali_datasets/test/74ba3bdc8c2f422a9e986a0522b0e6c5.wav does not exist....moving on.
# Skip: 74ba3bdc8c2f422a9e986a0522b0e6c5
# Saving Files from: afa903f29d06489189a6f77b4d1cda93
# 71: creating dataframe for afa903f29d06489189a6f77b4d1cda93
# Saving Files from: 3179c8442b78428380553a94f0f70603
# File: dali_datasets/test/3179c8442b78428380553a94f0f70603.wav does not exist....moving on.
# Skip: 3179c8442b78428380553a94f0f70603
# Saving Files from: 0091064bdc72469ca7096d3a0db74562
# 73: creating dataframe for 0091064bdc72469ca7096d3a0db74562
# Saving Files from: 1d257d06c8bb491ca1934516fd110b58
# 74: creating dataframe for 1d257d06c8bb491ca1934516fd110b58
# Saving Files from: 2fa1a8f3015d42f387b78b4f3601acd4
# 75: creating dataframe for 2fa1a8f3015d42f387b78b4f3601acd4
# Saving Files from: 568ca0f42dda4d65af3ab101931b190f
# 76: creating dataframe for 568ca0f42dda4d65af3ab101931b190f
# Saving Files from: 5ee5d7662fcb42a683f64490dec96dcf
# 77: creating dataframe for 5ee5d7662fcb42a683f64490dec96dcf
# Saving Files from: 215a11a438ce4963be16212d71d68aaa
# 78: creating dataframe for 215a11a438ce4963be16212d71d68aaa
# Saving Files from: 38bc6e2c27334a9b8af3a7e1244cbfc1
# 79: creating dataframe for 38bc6e2c27334a9b8af3a7e1244cbfc1
# Saving Files from: 749a37373ef447949d520add48f55852
# File: dali_datasets/test/749a37373ef447949d520add48f55852.wav does not exist....moving on.
# Skip: 749a37373ef447949d520add48f55852
# Saving Files from: 5d6ce8b5378f41c6a9906d905c0d3c4f
# 81: creating dataframe for 5d6ce8b5378f41c6a9906d905c0d3c4f
# Saving Files from: ff348b1ede1043d8a1ab033b326f8056
# 82: creating dataframe for ff348b1ede1043d8a1ab033b326f8056
# Saving Files from: 607bb216fd9c49f88604be23bb3bc87c
# 83: creating dataframe for 607bb216fd9c49f88604be23bb3bc87c
# Saving Files from: ff33ea7be69e46e4bf154c1d6f3ae45b
# 84: creating dataframe for ff33ea7be69e46e4bf154c1d6f3ae45b
# Saving Files from: 60725a5ecd6f4605abac479d3cacbc98
# 85: creating dataframe for 60725a5ecd6f4605abac479d3cacbc98
# Saving Files from: 0ab34ce9fa6a4da38a1ec894f0e3a1f4
# File: dali_datasets/test/0ab34ce9fa6a4da38a1ec894f0e3a1f4.wav does not exist....moving on.
# Skip: 0ab34ce9fa6a4da38a1ec894f0e3a1f4
# Saving Files from: 36113f05922b4752bf4d7b30625a1b1c
# 87: creating dataframe for 36113f05922b4752bf4d7b30625a1b1c
# Saving Files from: 5192ab7883f74bb588f65fcd1b0390e1
# 88: creating dataframe for 5192ab7883f74bb588f65fcd1b0390e1
# Saving Files from: 5a29a6f2734b4f0c9cce34a4cd165728
# 89: creating dataframe for 5a29a6f2734b4f0c9cce34a4cd165728
# Saving Files from: 11c7c693bce64765894d53e54b6931e5
# 90: creating dataframe for 11c7c693bce64765894d53e54b6931e5
# Saving Files from: 42c7fa8a79df4a19932c2fef2ede7b58
# File: dali_datasets/test/42c7fa8a79df4a19932c2fef2ede7b58.wav does not exist....moving on.
# Skip: 42c7fa8a79df4a19932c2fef2ede7b58
# Saving Files from: 2c701bb2320a42fab40a8ee181a1aca5
# 92: creating dataframe for 2c701bb2320a42fab40a8ee181a1aca5
# Saving Files from: 9e75c3f388f24b21867897c32b42f779
# 93: creating dataframe for 9e75c3f388f24b21867897c32b42f779
# Saving Files from: c6c732cc41b54a8fa558db076e8b8d93
# 94: creating dataframe for c6c732cc41b54a8fa558db076e8b8d93
# Saving Files from: acccdc83bcab484a9fe4888d3f7069d9
# File: dali_datasets/test/acccdc83bcab484a9fe4888d3f7069d9.wav does not exist....moving on.
# Skip: acccdc83bcab484a9fe4888d3f7069d9
# Saving Files from: 88b0eced01684eb09e3626277c447068
# 96: creating dataframe for 88b0eced01684eb09e3626277c447068
# Saving Files from: c1dd7a278763461e9d5782be2c9c2b0b
# File: dali_datasets/test/c1dd7a278763461e9d5782be2c9c2b0b.wav does not exist....moving on.
# Skip: c1dd7a278763461e9d5782be2c9c2b0b
# Saving Files from: eafc8fe7d1c241618fa718ba1c53ac3e
# File: dali_datasets/test/eafc8fe7d1c241618fa718ba1c53ac3e.wav does not exist....moving on.
# Skip: eafc8fe7d1c241618fa718ba1c53ac3e
# Saving Files from: 6ebfa46300b347ecb12389add06e6d28
# 99: creating dataframe for 6ebfa46300b347ecb12389add06e6d28
# Saving Files from: 84cfa398e56f49aa8454ceab82ed933e
# 100: creating dataframe for 84cfa398e56f49aa8454ceab82ed933e
# Saving Files from: 92a328c58c864d5ca904f8bfa2df5515
# 101: creating dataframe for 92a328c58c864d5ca904f8bfa2df5515
# Saving Files from: cdf1f6338e5948a3acc85fd605fe4ec0
# 102: creating dataframe for cdf1f6338e5948a3acc85fd605fe4ec0
# Saving Files from: cfbd301d613b4041aff2f3ac0d246e56
# 103: creating dataframe for cfbd301d613b4041aff2f3ac0d246e56
# Saving Files from: 289a42d903ca4b8fb5e6087a47a031a3
# 104: creating dataframe for 289a42d903ca4b8fb5e6087a47a031a3
# Saving Files from: 40e95f7040dc406f9387e3ba6352d630
# 105: creating dataframe for 40e95f7040dc406f9387e3ba6352d630
# Saving Files from: 6167718ba7be41fc8cfc4f2e37c53ea4
# 106: creating dataframe for 6167718ba7be41fc8cfc4f2e37c53ea4
# Saving Files from: 8bb8c6bb7be24aee8beac52b68525604
# 107: creating dataframe for 8bb8c6bb7be24aee8beac52b68525604
# Saving Files from: b6de4d53fad94fe3972c6468e93a16c2
# 108: creating dataframe for b6de4d53fad94fe3972c6468e93a16c2
# Saving Files from: 5f634adeb0274ffab156683d092c43ab
# File: dali_datasets/test/5f634adeb0274ffab156683d092c43ab.wav does not exist....moving on.
# 222: creating dataframe for 6f3d8aad9990437c91d3f9d77cd51f11
# Saving Files from: 97c9e2b0ffa34f259e21d5ec0752faf6
# 223: creating dataframe for 97c9e2b0ffa34f259e21d5ec0752faf6
# Saving Files from: 06e8322a90954a028762888dfe3e70cf
# 224: creating dataframe for 06e8322a90954a028762888dfe3e70cf
# Saving Files from: 6b4369a6c8704cc4936368fc85dbfa5b
# 225: creating dataframe for 6b4369a6c8704cc4936368fc85dbfa5b
# Saving Files from: 2bdce213821c491293061bbd4a5b6ac1
# 226: creating dataframe for 2bdce213821c491293061bbd4a5b6ac1
# Saving Files from: b48c72da216e40bbb290ce726e926534
# 227: creating dataframe for b48c72da216e40bbb290ce726e926534
# Saving Files from: de1c0929af0e4026b705b46b88aead33
# File: dali_datasets/test/de1c0929af0e4026b705b46b88aead33.wav does not exist....moving on.
# Skip: de1c0929af0e4026b705b46b88aead33
# Saving Files from: adeeffbf18cc4c6cb3de6af56cb407cd
# 229: creating dataframe for adeeffbf18cc4c6cb3de6af56cb407cd
# Saving Files from: 00c4f2efb0b143728113fad1a78d6ce3
# File: dali_datasets/test/00c4f2efb0b143728113fad1a78d6ce3.wav does not exist....moving on.
# Skip: 00c4f2efb0b143728113fad1a78d6ce3
# Saving Files from: 0348e3799c164649bc8bd0da206062f3
# 231: creating dataframe for 0348e3799c164649bc8bd0da206062f3
# Saving Files from: 2c07e4cb175d4d5b8a0e2b6291e3f917
# 232: creating dataframe for 2c07e4cb175d4d5b8a0e2b6291e3f917
# Saving Files from: 15c1f27eaaa64f5fb9e3cfebff8d2a91
# 233: creating dataframe for 15c1f27eaaa64f5fb9e3cfebff8d2a91
# Saving Files from: 1c6112908256403faa9812bb7930a8a1
# 234: creating dataframe for 1c6112908256403faa9812bb7930a8a1
# Saving Files from: 79c46b538c4a42b4ade34c2e78b663d5
# 235: creating dataframe for 79c46b538c4a42b4ade34c2e78b663d5
# Saving Files from: 6dae25f87a5f45779e0adf97b7537552
# 236: creating dataframe for 6dae25f87a5f45779e0adf97b7537552
# Saving Files from: 73972858ae3d464f9f8bf8dcd562aafd
# 237: creating dataframe for 73972858ae3d464f9f8bf8dcd562aafd
# Saving Files from: b0c1c41a5a024f47ae1eca7a8b5ca59b
# 238: creating dataframe for b0c1c41a5a024f47ae1eca7a8b5ca59b
# Saving Files from: b1b6bc336f78441b8b31da555ccf59d8
# File: dali_datasets/test/b1b6bc336f78441b8b31da555ccf59d8.wav does not exist....moving on.
# Skip: b1b6bc336f78441b8b31da555ccf59d8

# %%
#
#  Saving Metadata file...
#
metadata_df.to_csv(f"{destination_dir}/metadata.csv",index=False)

# %% [markdown]
# # Sampling Utterance Files

# %%
# this finds the file, parses the file, then plays the snippet.
dali_id = dali_test_metadata_df['DALI_ID'].sample(1).iloc[0]
entry = dali_data[dali_id]
utt_array = find_utterances(entry)
ID = 23
song_utt = utt_array[ID]
filename = f"{destination_dir}/{entry.info['id']}_{ID}.wav"
if os.path.isfile(filename):
    wav, sr = torchaudio.load(filename)
else:
    print(f"File: {filename} does not exist.")

print(song_utt['text'])
Audio(wav,rate=sr)
# Out:
# and stare
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Total Duration of DALI Test (as utterances)

# %%
total_song_duration = 0
for i, dali_id in enumerate(dali_ids):
    entry = dali_data[dali_id]
    utt_array = find_utterances(entry)
    total_song_duration += np.sum(np.array([utt_song['duration'] for utt_song in utt_array]))
print(f"Total Duration of Entry: {total_song_duration:.1f}s or {total_song_duration/60:.1f}min or {total_song_duration/3600:.2f}hr")
# Out:
# Total Duration of Entry: 32696.4s or 544.9min or 9.08hr

# %% [markdown]
# # Looking for all artists

# %%
# expected number of songs by version...
dali_version1_nsongs = 5358
dali_version2_nsongs = 7756

artists = list()

for sond_id, entry in tqdm.tqdm(dali_data.items(), desc="Processing"):
    artists.append(entry.info['artist'])

print(f"Found {len(set(artists))} artists")
# Out:
# Processing: 100%|███████████████████████████████████████████████████████████████████████| 5358/5358 [00:00<00:00, 128482.95it/s]
# Found 2274 artists

# %%
# Top 20 Artists
ds = pd.Series(artists)
ds.value_counts().iloc[0:20]
# Out:
# Demi Lovato         43
# Muse                39
# Taylor Swift        29
# Volbeat             28
# Linkin Park         28
# ABBA                27
# Die Ärzte           27
# Green Day           27
# Take That           24
# Elvis Presley       24
# Glee Cast           24
# Mumford & Sons      23
# Avril Lavigne       23
# Queen               23
# The Beatles         22
# System Of A Down    22
# Metallica           21
# Madonna             21
# Three Days Grace    21
# Blink-182           21
# Name: count, dtype: int64

# %% [markdown]
# ## Get All Taylor Lyrics in DALI and Save to Disk

# %%
SAVE_DIR = os.getcwd()+"/transcripts/"
if not os.path.exists(SAVE_DIR):
    os.mkdir(SAVE_DIR)

# %%
ARTIST_DIR = SAVE_DIR+"/taylor_swift"
if not os.path.exists(ARTIST_DIR):
    os.mkdir(ARTIST_DIR)

artist_count = 0
for song_id, entry in tqdm.tqdm(dali_data.items(), desc="Processing"):
    if entry.info['artist'].lower() == "taylor swift":
        artist_count += 1
        paras = [v for d in entry.annotations['annot']['paragraphs'] for k,v in d.items() if k=="text"]
        lyrics = '\n\n'.join(paras)
        with open(f"{ARTIST_DIR}/{song_id}.txt", 'a') as file:
            file.write(lyrics)
print(f"Found {artist_count} Taylor Swift Songs")
# Out:
# Processing: 100%|███████████████████████████████████████████████████████████████████████| 5358/5358 [00:00<00:00, 276816.62it/s]
# Found 29 Taylor Swift Songs

# %% [markdown]
# ## Get All Muse Lyrics in DALI and Save to Disk

# %%
ARTIST_DIR = SAVE_DIR+"/muse"
if not os.path.exists(ARTIST_DIR):
    os.mkdir(ARTIST_DIR)

artist_count = 0
for song_id, entry in tqdm.tqdm(dali_data.items(), desc="Processing"):
    if entry.info['artist'].lower() == "muse":
        artist_count += 1
        paras = [v for d in entry.annotations['annot']['paragraphs'] for k,v in d.items() if k=="text"]
        lyrics = '\n\n'.join(paras)
        with open(f"{ARTIST_DIR}/{song_id}.txt", 'a') as file:
            file.write(lyrics)
print(f"Found {artist_count} Muse Songs")
# Out:
# Processing: 100%|███████████████████████████████████████████████████████████████████████| 5358/5358 [00:00<00:00, 248376.22it/s]
# Found 39 Muse Songs

# %% [markdown]
# # Clean up Transcripts from Directories
