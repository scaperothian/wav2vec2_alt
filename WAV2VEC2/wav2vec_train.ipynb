# %% [markdown]
# # Fine Tuning Pre-trained WAV2VEC Using DSing Train
#
# ## Summary
#
# 1. Loading WAV2VEC model
# 2. Creating a Huggingface dataset for batch processing by Cropping the DSing Dataset described below (8 songs for each split, 1.5seconds max)
#
# The dataset is cropped to allow for processing examples for this notebook.  in the actual processing, it will look different.
#
# ## DSing Dataset
#
# Reading data from DSing Dataset.  Filesystem formatted this way to convert easily to huggingface dataset.
#
# where: <br>
# dev/test/trainX are datasets split.<br>
# \[split\]_text contains transcript for the snippet.<br>
# \[split\]_spk2gender contains information about gender for snippet.<br>
#
# Tests Split: 480 Utterances, 48 minutes<br>
# Dev Split: 482 Utterances, 41 minutes<br>
# Train1 Split: 8794 Utterances, 15.1 hours<br>
# Train3 Split: 25526 Utterances, 44.7 hours<br>
# Train30 Split: 268,392 Utterances, 149.1 hours<br>
#
# sing_300x30x2/dataset/<br>
# ├── dev/<br>
# ├───| metadata.csv<br>
# &ensp;&ensp;&ensp;&ensp;&ensp;&ensp;&ensp;&nbsp;| \<audio files\>.wav<br>
# ├── dev_spk2gender<br>
# ├── dev_text<br>
# ├── test/<br>
# ├───| metadata.csv<br>
# &ensp;&ensp;&ensp;&ensp;&ensp;&ensp;&ensp;&nbsp;| \<audio files\>.wav<br>
# ├── test_spk2gender<br>
# ├── test_text<br>
# ├── train1/<br>
# ├───| metadata.csv<br>
# &ensp;&ensp;&ensp;&ensp;&ensp;&ensp;&ensp;&nbsp;| \<audio files\>.wav<br>
# ├── train1_spk2gender<br>
# ├── train1_text<br>
# ├── train3/<br>
# ├───| metadata.csv<br>
# &ensp;&ensp;&ensp;&ensp;&ensp;&ensp;&ensp;&nbsp;| \<audio files\>.wav<br>
# ├── train3_spk2gender<br>
# └── train3_text<br>
# ├── train30/<br>
# ├───| metadata.csv<br>
# &ensp;&ensp;&ensp;&ensp;&ensp;&ensp;&ensp;&nbsp;| \<audio files\>.wav<br>
# ├── train30_spk2gender<br>
# ├── train30_text<br>

# %% [markdown]
# # For Colab Training

# %%
from google.colab import drive
#drive.flush_and_unmount()
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
drive.flush_and_unmount()

# %%
#
# Curated DAMP 300x30x2 dataset (DSing) unpacked and preprocessed into
# child folder dataset/. DSing is around 1.9GB after being preprocessed.
#

#!unzip /content/drive/MyDrive/damp_dataset_20240410.zip -d /
# !unzip /content/drive/MyDrive/dali_test_utt_dataset.zip -d /
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /dali_datasets/test/5991209bcde54446a428d0d40cfd2d82_45.wav
#   inflating: /dali_datasets/test/4986c16294c247f1a01dd92793a7e2b3_50.wav
#   inflating: /dali_datasets/test/ae91bcda73944695b7756ddc066c3e02_7.wav
#   inflating: /dali_datasets/test/45e0ccbdf76f4060af50f95d93492755_3.wav
#   inflating: /dali_datasets/test/06e8322a90954a028762888dfe3e70cf_47.wav
#   inflating: /dali_datasets/test/6dae25f87a5f45779e0adf97b7537552_11.wav
#   inflating: /dali_datasets/test/9fe1d4ff035d43839e7556cd7293d525_25.wav
#   inflating: /dali_datasets/test/ccd577a699864e469dd77dc04de02955_24.wav
#   inflating: /dali_datasets/test/84cfa398e56f49aa8454ceab82ed933e_6.wav
#   inflating: /dali_datasets/test/57a743bbbc7c472788d258f977c11cee_27.wav
#   inflating: /dali_datasets/test/7357de99882d49cb9a0564a8ce4d60f4_19.wav
#   inflating: /dali_datasets/test/57a743bbbc7c472788d258f977c11cee_33.wav
#   inflating: /dali_datasets/test/38dd5ffcbdaf440ebd53647eaf0b7b3f_16.wav
#   inflating: /dali_datasets/test/ccd577a699864e469dd77dc04de02955_30.wav
#   inflating: /dali_datasets/test/494472a1e4f0459198e1a11b8eec1bf0_13.wav
#   inflating: /dali_datasets/test/f45833d95ffc48a092874ed9c01bcad8_2.wav
#   inflating: /dali_datasets/test/3852f692f72e4c43bbcdb6fe021ea087_60.wav
#   inflating: /dali_datasets/test/9fe1d4ff035d43839e7556cd7293d525_31.wav
#   inflating: /dali_datasets/test/c969f501dfcd4921b49270880cee7b97_0.wav
#   inflating: /dali_datasets/test/f3bec6c19cf84f9295d5b1b112446727_23.wav
#   inflating: /dali_datasets/test/a961a043ea524ed1b5e91bf6d5bbc5db_15.wav
#   inflating: /dali_datasets/test/c7b1ed7e5b1e427489a00273916376cc_1.wav
#   inflating: /dali_datasets/test/d41b06367bcc4e3085984a6766a8f2d2_2.wav
#   inflating: /dali_datasets/test/86fd9ce08a084c3f8016043904788f6f_31.wav
#   inflating: /dali_datasets/test/09292a9d8d6b4e008d270da087dbf51d_46.wav
#   inflating: /dali_datasets/test/8cffd4299028493592a18e132d412e9c_29.wav
#   inflating: /dali_datasets/test/3667aa608d09487086893f3f8b0aecb2_47.wav
#   inflating: /dali_datasets/test/d9d748696b5949d993bdca21a49a4ebe_9.wav
#   inflating: /dali_datasets/test/d7418a26f45d46f098889cc1997dddc7_22.wav
#   inflating: /dali_datasets/test/0b632ce605a345c3b4317ed14f922354_5.wav
#   inflating: /dali_datasets/test/57f01768c0174b109a065061bd428251_29.wav
#   inflating: /dali_datasets/test/7ddab4ab4a0e43548f2674cbf34a2e5f_4.wav
#   inflating: /dali_datasets/test/adeeffbf18cc4c6cb3de6af56cb407cd_36.wav
#   inflating: /dali_datasets/test/7a14ac26f9624922859b33caede07b07_7.wav
#   inflating: /dali_datasets/test/dfedd81d64c2461c83897627e0f25d25_9.wav
#   inflating: /dali_datasets/test/38dd5ffcbdaf440ebd53647eaf0b7b3f_8.wav
#   inflating: /dali_datasets/test/e6f7c7bb2d3a465f8fb495038778c28c_3.wav
#   inflating: /dali_datasets/test/41adec28c9b6444baf6d38c0fa79247b_4.wav
#   inflating: /dali_datasets/test/adeeffbf18cc4c6cb3de6af56cb407cd_22.wav
#   inflating: /dali_datasets/test/3667aa608d09487086893f3f8b0aecb2_53.wav
#   inflating: /dali_datasets/test/38bc6e2c27334a9b8af3a7e1244cbfc1_7.wav
#   inflating: /dali_datasets/test/d7418a26f45d46f098889cc1997dddc7_36.wav
#   inflating: /dali_datasets/test/1785a186119f434ba37583887326b028_5.wav
#   inflating: /dali_datasets/test/41adec28c9b6444baf6d38c0fa79247b_10.wav
#   inflating: /dali_datasets/test/86fd9ce08a084c3f8016043904788f6f_25.wav
#   inflating: /dali_datasets/test/7af9d63e524f4b0d93c841822660920d_45.wav
#   inflating: /dali_datasets/test/2710e4d6a4e3478fbd0ed1706840ff21_11.wav
#   inflating: /dali_datasets/test/dd1a1d9b3fb84310ab4e559415c0aa52_14.wav
#   inflating: /dali_datasets/test/8cffd4299028493592a18e132d412e9c_15.wav
#   inflating: /dali_datasets/test/a8762df0f6724497b8d9ccc1308cee25_51.wav
#   inflating: /dali_datasets/test/a961a043ea524ed1b5e91bf6d5bbc5db_29.wav
#   inflating: /dali_datasets/test/92a328c58c864d5ca904f8bfa2df5515_13.wav
#   inflating: /dali_datasets/test/452037efa1284176b7aa7b80a05afa95_32.wav
#   inflating: /dali_datasets/test/57f01768c0174b109a065061bd428251_15.wav
#   inflating: /dali_datasets/test/2fd0fbfa0ff34734a0beb4730c5a761a_36.wav
#   inflating: /dali_datasets/test/b6de4d53fad94fe3972c6468e93a16c2_22.wav
#   inflating: /dali_datasets/test/41adec28c9b6444baf6d38c0fa79247b_38.wav
#   inflating: /dali_datasets/test/4cec9fa30b0c4ed78f4f99b63a9866a6_12.wav
#   inflating: /dali_datasets/test/401559f30dc04330a97bef1cedf474fb_13.wav
#   inflating: /dali_datasets/test/2bdce213821c491293061bbd4a5b6ac1_13.wav
#   inflating: /dali_datasets/test/2fd0fbfa0ff34734a0beb4730c5a761a_22.wav
#   inflating: /dali_datasets/test/b6de4d53fad94fe3972c6468e93a16c2_36.wav
#   inflating: /dali_datasets/test/452037efa1284176b7aa7b80a05afa95_26.wav
#   inflating: /dali_datasets/test/86fd9ce08a084c3f8016043904788f6f_19.wav
#   inflating: /dali_datasets/test/dd1a1d9b3fb84310ab4e559415c0aa52_28.wav
#   inflating: /dali_datasets/test/ff33ea7be69e46e4bf154c1d6f3ae45b_21.wav
#   inflating: /dali_datasets/test/a8762df0f6724497b8d9ccc1308cee25_45.wav
#   inflating: /dali_datasets/test/9994eba1573e467994bea7445554d2e9_43.wav
#   inflating: /dali_datasets/test/f3def952d1a24a649171ee352313c977_26.wav
#   inflating: /dali_datasets/test/0e51f03136de44339626fd6af72ee646_33.wav
#   inflating: /dali_datasets/test/38bc6e2c27334a9b8af3a7e1244cbfc1_30.wav
#   inflating: /dali_datasets/test/874ff998bef04d939b8b21f7434abacd_31.wav
#   inflating: /dali_datasets/test/155c1427eb074347b7fc4dc89ccd2a27_70.wav
#   inflating: /dali_datasets/test/b63d71b7ec6b4c5e9f53a87f83fcd73e_22.wav
#   inflating: /dali_datasets/test/e629670ee23a4bcd8d4c85f40b296e98_32.wav
#   inflating: /dali_datasets/test/6c180ba4d4314ee2b8dbf3b8ff3e6597_70.wav
#   inflating: /dali_datasets/test/e629670ee23a4bcd8d4c85f40b296e98_26.wav
#   inflating: /dali_datasets/test/0b59aef984da4bfc9166ee96790e319b_3.wav
#   inflating: /dali_datasets/test/a828936b0cc446469bde58458fa3376e_48.wav
#   inflating: /dali_datasets/test/401559f30dc04330a97bef1cedf474fb_7.wav
#   inflating: /dali_datasets/test/6c180ba4d4314ee2b8dbf3b8ff3e6597_64.wav
#   inflating: /dali_datasets/test/b48c72da216e40bbb290ce726e926534_13.wav
#   inflating: /dali_datasets/test/57f01768c0174b109a065061bd428251_4.wav
#   inflating: /dali_datasets/test/0314e07bdfe74bfa87cd0b8b9aca3418_10.wav
#   inflating: /dali_datasets/test/874ff998bef04d939b8b21f7434abacd_25.wav
#   inflating: /dali_datasets/test/155c1427eb074347b7fc4dc89ccd2a27_64.wav
#   inflating: /dali_datasets/test/b63d71b7ec6b4c5e9f53a87f83fcd73e_36.wav
#   inflating: /dali_datasets/test/f3def952d1a24a649171ee352313c977_32.wav
#   inflating: /dali_datasets/test/9994eba1573e467994bea7445554d2e9_57.wav
#   inflating: /dali_datasets/test/0e51f03136de44339626fd6af72ee646_27.wav
#   inflating: /dali_datasets/test/38bc6e2c27334a9b8af3a7e1244cbfc1_24.wav
#   inflating: /dali_datasets/test/53e2da93b8a84468b6f1264055a18001_32.wav
#   inflating: /dali_datasets/test/8bb8c6bb7be24aee8beac52b68525604_26.wav
#   inflating: /dali_datasets/test/9f128efc665545899db1ace419f1c002_13.wav
#   inflating: /dali_datasets/test/83741a6e941c47cc9951c30583b812c9_0.wav
#   inflating: /dali_datasets/test/a828936b0cc446469bde58458fa3376e_60.wav
#   inflating: /dali_datasets/test/6167718ba7be41fc8cfc4f2e37c53ea4_62.wav
#   inflating: /dali_datasets/test/b60f5426792642f9a9c59717d0ec3b23_13.wav
#   inflating: /dali_datasets/test/b1c2aa195fbf4262873c893af7926abe_48.wav
#   inflating: /dali_datasets/test/6c180ba4d4314ee2b8dbf3b8ff3e6597_58.wav
#   inflating: /dali_datasets/test/8bb8c6bb7be24aee8beac52b68525604_32.wav
#   inflating: /dali_datasets/test/38bc6e2c27334a9b8af3a7e1244cbfc1_18.wav
#   inflating: /dali_datasets/test/155c1427eb074347b7fc4dc89ccd2a27_58.wav
#   inflating: /dali_datasets/test/874ff998bef04d939b8b21f7434abacd_19.wav
#   inflating: /dali_datasets/test/53e2da93b8a84468b6f1264055a18001_26.wav
#   inflating: /dali_datasets/test/b3639d60a49e45578a201d910f36c44c_47.wav
#   inflating: /dali_datasets/test/60444e5fa89e440da33bb00363985a0b_8.wav
#   inflating: /dali_datasets/test/0b632ce605a345c3b4317ed14f922354_38.wav
#   inflating: /dali_datasets/test/2a59f9edbc414acf9c10374b9a97c388_18.wav
#   inflating: /dali_datasets/test/2b2a69736d924657afc12188f3eb56ee_16.wav
#   inflating: /dali_datasets/test/9942d02f1525441a8114f1d28ffb3d30_22.wav
#   inflating: /dali_datasets/test/7357de99882d49cb9a0564a8ce4d60f4_6.wav
#   inflating: /dali_datasets/test/87e90ee8fdd749fe821f629e67addc94_38.wav
#   inflating: /dali_datasets/test/0b59aef984da4bfc9166ee96790e319b_18.wav
#   inflating: /dali_datasets/test/0a1c2a896fa34688b86547f4317a7733_38.wav
#   inflating: /dali_datasets/test/22cf71f0eafb4ad583c7642c803be421_7.wav
#   inflating: /dali_datasets/test/568ca0f42dda4d65af3ab101931b190f_1.wav
#   inflating: /dali_datasets/test/63543c65e84041dcbb5a9e1eb900d236_21.wav
#   inflating: /dali_datasets/test/cfbd301d613b4041aff2f3ac0d246e56_38.wav
#   inflating: /dali_datasets/test/a828936b0cc446469bde58458fa3376e_0.wav
#   inflating: /dali_datasets/test/85195d4a91a846488942e534246055f7_23.wav
#   inflating: /dali_datasets/test/8d7f9342cf644e8797f4d7d0402a75bd_2.wav
#   inflating: /dali_datasets/test/a59e44a4c910443a87f068b177200fdc_41.wav
#   inflating: /dali_datasets/test/1ffe2e044701432dbad931dacb4bc543_26.wav
#   inflating: /dali_datasets/test/c7874dfd65ef434e97712601b153bceb_33.wav
#   inflating: /dali_datasets/test/cfbd301d613b4041aff2f3ac0d246e56_10.wav
#   inflating: /dali_datasets/test/2a59f9edbc414acf9c10374b9a97c388_24.wav
#   inflating: /dali_datasets/test/11c7c693bce64765894d53e54b6931e5_36.wav
#   inflating: /dali_datasets/test/f13f2d18c8314b65aa0b5697b48151f4_35.wav
#   inflating: /dali_datasets/test/0a1c2a896fa34688b86547f4317a7733_10.wav
#   inflating: /dali_datasets/test/0b59aef984da4bfc9166ee96790e319b_24.wav
#   inflating: /dali_datasets/test/ae62daf4c9b34bdba090bc5a1906fd77_3.wav
#   inflating: /dali_datasets/test/2aa96389947f44868e00eafb9bd6970d_21.wav
#   inflating: /dali_datasets/test/87e90ee8fdd749fe821f629e67addc94_10.wav
#   inflating: /dali_datasets/test/0091064bdc72469ca7096d3a0db74562_43.wav
#   inflating: /dali_datasets/test/0b59aef984da4bfc9166ee96790e319b_30.wav
#   inflating: /dali_datasets/test/2211635e2a714fcf8247878ef5aac1cc_4.wav
#   inflating: /dali_datasets/test/11c7c693bce64765894d53e54b6931e5_22.wav
#   inflating: /dali_datasets/test/f13f2d18c8314b65aa0b5697b48151f4_21.wav
#   inflating: /dali_datasets/test/85195d4a91a846488942e534246055f7_37.wav
#   inflating: /dali_datasets/test/1ffe2e044701432dbad931dacb4bc543_32.wav
#   inflating: /dali_datasets/test/a59e44a4c910443a87f068b177200fdc_55.wav
#   inflating: /dali_datasets/test/0b632ce605a345c3b4317ed14f922354_10.wav
#   inflating: /dali_datasets/test/c7874dfd65ef434e97712601b153bceb_27.wav
#   inflating: /dali_datasets/test/ff348b1ede1043d8a1ab033b326f8056_5.wav
#   inflating: /dali_datasets/test/2a59f9edbc414acf9c10374b9a97c388_30.wav
#   inflating: /dali_datasets/test/e61d7f0bf9ad4947885ca6e0b664b23d_43.wav
#   inflating: /dali_datasets/test/0b59aef984da4bfc9166ee96790e319b_31.wav
#   inflating: /dali_datasets/test/0091064bdc72469ca7096d3a0db74562_42.wav
#   inflating: /dali_datasets/test/87e90ee8fdd749fe821f629e67addc94_11.wav
#   inflating: /dali_datasets/test/2aa96389947f44868e00eafb9bd6970d_20.wav
#   inflating: /dali_datasets/test/2a59f9edbc414acf9c10374b9a97c388_31.wav
#   inflating: /dali_datasets/test/e61d7f0bf9ad4947885ca6e0b664b23d_42.wav
#   inflating: /dali_datasets/test/ff348b1ede1043d8a1ab033b326f8056_4.wav
#   inflating: /dali_datasets/test/c7874dfd65ef434e97712601b153bceb_26.wav
#   inflating: /dali_datasets/test/0b632ce605a345c3b4317ed14f922354_11.wav
#   inflating: /dali_datasets/test/a59e44a4c910443a87f068b177200fdc_54.wav
#   inflating: /dali_datasets/test/1ffe2e044701432dbad931dacb4bc543_33.wav
#   inflating: /dali_datasets/test/85195d4a91a846488942e534246055f7_36.wav
#   inflating: /dali_datasets/test/f13f2d18c8314b65aa0b5697b48151f4_20.wav
#   inflating: /dali_datasets/test/11c7c693bce64765894d53e54b6931e5_23.wav
#   inflating: /dali_datasets/test/2211635e2a714fcf8247878ef5aac1cc_5.wav
#   inflating: /dali_datasets/test/f13f2d18c8314b65aa0b5697b48151f4_34.wav
#   inflating: /dali_datasets/test/11c7c693bce64765894d53e54b6931e5_37.wav
#   inflating: /dali_datasets/test/2a59f9edbc414acf9c10374b9a97c388_25.wav
#   inflating: /dali_datasets/test/cfbd301d613b4041aff2f3ac0d246e56_11.wav
#   inflating: /dali_datasets/test/c7874dfd65ef434e97712601b153bceb_32.wav
#   inflating: /dali_datasets/test/1ffe2e044701432dbad931dacb4bc543_27.wav
#   inflating: /dali_datasets/test/a59e44a4c910443a87f068b177200fdc_40.wav
#   inflating: /dali_datasets/test/8d7f9342cf644e8797f4d7d0402a75bd_3.wav
#   inflating: /dali_datasets/test/85195d4a91a846488942e534246055f7_22.wav
#   inflating: /dali_datasets/test/ae62daf4c9b34bdba090bc5a1906fd77_2.wav
#   inflating: /dali_datasets/test/0b59aef984da4bfc9166ee96790e319b_25.wav
#   inflating: /dali_datasets/test/0a1c2a896fa34688b86547f4317a7733_11.wav
#   inflating: /dali_datasets/test/568ca0f42dda4d65af3ab101931b190f_0.wav
#   inflating: /dali_datasets/test/22cf71f0eafb4ad583c7642c803be421_6.wav
#   inflating: /dali_datasets/test/0a1c2a896fa34688b86547f4317a7733_39.wav
#   inflating: /dali_datasets/test/a828936b0cc446469bde58458fa3376e_1.wav
#   inflating: /dali_datasets/test/cfbd301d613b4041aff2f3ac0d246e56_39.wav
#   inflating: /dali_datasets/test/63543c65e84041dcbb5a9e1eb900d236_20.wav
#   inflating: /dali_datasets/test/a59e44a4c910443a87f068b177200fdc_68.wav
#   inflating: /dali_datasets/test/2a59f9edbc414acf9c10374b9a97c388_19.wav
#   inflating: /dali_datasets/test/0b632ce605a345c3b4317ed14f922354_39.wav
#   inflating: /dali_datasets/test/b3639d60a49e45578a201d910f36c44c_46.wav
#   inflating: /dali_datasets/test/60444e5fa89e440da33bb00363985a0b_9.wav
#   inflating: /dali_datasets/test/0b59aef984da4bfc9166ee96790e319b_19.wav
#   inflating: /dali_datasets/test/87e90ee8fdd749fe821f629e67addc94_39.wav
#   inflating: /dali_datasets/test/7357de99882d49cb9a0564a8ce4d60f4_7.wav
#   inflating: /dali_datasets/test/9942d02f1525441a8114f1d28ffb3d30_23.wav
#   inflating: /dali_datasets/test/2b2a69736d924657afc12188f3eb56ee_17.wav
#   inflating: /dali_datasets/test/6c180ba4d4314ee2b8dbf3b8ff3e6597_59.wav
#   inflating: /dali_datasets/test/b1c2aa195fbf4262873c893af7926abe_49.wav
#   inflating: /dali_datasets/test/b60f5426792642f9a9c59717d0ec3b23_12.wav
#   inflating: /dali_datasets/test/53e2da93b8a84468b6f1264055a18001_27.wav
#   inflating: /dali_datasets/test/874ff998bef04d939b8b21f7434abacd_18.wav
#   inflating: /dali_datasets/test/155c1427eb074347b7fc4dc89ccd2a27_59.wav
#   inflating: /dali_datasets/test/38bc6e2c27334a9b8af3a7e1244cbfc1_19.wav
#   inflating: /dali_datasets/test/8bb8c6bb7be24aee8beac52b68525604_33.wav
#   inflating: /dali_datasets/test/8bb8c6bb7be24aee8beac52b68525604_27.wav
#   inflating: /dali_datasets/test/53e2da93b8a84468b6f1264055a18001_33.wav
#   inflating: /dali_datasets/test/6167718ba7be41fc8cfc4f2e37c53ea4_63.wav
#   inflating: /dali_datasets/test/a828936b0cc446469bde58458fa3376e_61.wav
#   inflating: /dali_datasets/test/83741a6e941c47cc9951c30583b812c9_1.wav
#   inflating: /dali_datasets/test/9f128efc665545899db1ace419f1c002_12.wav
#   inflating: /dali_datasets/test/57f01768c0174b109a065061bd428251_5.wav
#   inflating: /dali_datasets/test/b48c72da216e40bbb290ce726e926534_12.wav
#   inflating: /dali_datasets/test/6c180ba4d4314ee2b8dbf3b8ff3e6597_65.wav
#   inflating: /dali_datasets/test/a828936b0cc446469bde58458fa3376e_49.wav
#   inflating: /dali_datasets/test/401559f30dc04330a97bef1cedf474fb_6.wav
#   inflating: /dali_datasets/test/0b59aef984da4bfc9166ee96790e319b_2.wav
#   inflating: /dali_datasets/test/e629670ee23a4bcd8d4c85f40b296e98_27.wav
#   inflating: /dali_datasets/test/38bc6e2c27334a9b8af3a7e1244cbfc1_25.wav
#   inflating: /dali_datasets/test/0e51f03136de44339626fd6af72ee646_26.wav
#   inflating: /dali_datasets/test/9994eba1573e467994bea7445554d2e9_56.wav
#   inflating: /dali_datasets/test/f3def952d1a24a649171ee352313c977_33.wav
#   inflating: /dali_datasets/test/b63d71b7ec6b4c5e9f53a87f83fcd73e_37.wav
#   inflating: /dali_datasets/test/155c1427eb074347b7fc4dc89ccd2a27_65.wav
#   inflating: /dali_datasets/test/874ff998bef04d939b8b21f7434abacd_24.wav
#   inflating: /dali_datasets/test/0314e07bdfe74bfa87cd0b8b9aca3418_11.wav
#   inflating: /dali_datasets/test/2211635e2a714fcf8247878ef5aac1cc_48.wav
#   inflating: /dali_datasets/test/b63d71b7ec6b4c5e9f53a87f83fcd73e_23.wav
#   inflating: /dali_datasets/test/155c1427eb074347b7fc4dc89ccd2a27_71.wav
#   inflating: /dali_datasets/test/874ff998bef04d939b8b21f7434abacd_30.wav
#   inflating: /dali_datasets/test/38bc6e2c27334a9b8af3a7e1244cbfc1_31.wav
#   inflating: /dali_datasets/test/0e51f03136de44339626fd6af72ee646_32.wav
#   inflating: /dali_datasets/test/f3def952d1a24a649171ee352313c977_27.wav
#   inflating: /dali_datasets/test/9994eba1573e467994bea7445554d2e9_42.wav
#   inflating: /dali_datasets/test/6c180ba4d4314ee2b8dbf3b8ff3e6597_71.wav
#   inflating: /dali_datasets/test/e629670ee23a4bcd8d4c85f40b296e98_33.wav
#   inflating: /dali_datasets/test/b6de4d53fad94fe3972c6468e93a16c2_37.wav
#   inflating: /dali_datasets/test/2fd0fbfa0ff34734a0beb4730c5a761a_23.wav
#   inflating: /dali_datasets/test/2bdce213821c491293061bbd4a5b6ac1_12.wav
#   inflating: /dali_datasets/test/a8762df0f6724497b8d9ccc1308cee25_44.wav
#   inflating: /dali_datasets/test/dd1a1d9b3fb84310ab4e559415c0aa52_29.wav
#   inflating: /dali_datasets/test/ff33ea7be69e46e4bf154c1d6f3ae45b_20.wav
#   inflating: /dali_datasets/test/86fd9ce08a084c3f8016043904788f6f_18.wav
#   inflating: /dali_datasets/test/452037efa1284176b7aa7b80a05afa95_27.wav
#   inflating: /dali_datasets/test/452037efa1284176b7aa7b80a05afa95_33.wav
#   inflating: /dali_datasets/test/92a328c58c864d5ca904f8bfa2df5515_12.wav
#   inflating: /dali_datasets/test/a961a043ea524ed1b5e91bf6d5bbc5db_28.wav
#   inflating: /dali_datasets/test/a8762df0f6724497b8d9ccc1308cee25_50.wav
#   inflating: /dali_datasets/test/8cffd4299028493592a18e132d412e9c_14.wav
#   inflating: /dali_datasets/test/401559f30dc04330a97bef1cedf474fb_12.wav
#   inflating: /dali_datasets/test/4cec9fa30b0c4ed78f4f99b63a9866a6_13.wav
#   inflating: /dali_datasets/test/41adec28c9b6444baf6d38c0fa79247b_39.wav
#   inflating: /dali_datasets/test/b6de4d53fad94fe3972c6468e93a16c2_23.wav
#   inflating: /dali_datasets/test/2fd0fbfa0ff34734a0beb4730c5a761a_37.wav
#   inflating: /dali_datasets/test/57f01768c0174b109a065061bd428251_14.wav
#   inflating: /dali_datasets/test/41adec28c9b6444baf6d38c0fa79247b_11.wav
#   inflating: /dali_datasets/test/1785a186119f434ba37583887326b028_4.wav
#   inflating: /dali_datasets/test/d7418a26f45d46f098889cc1997dddc7_37.wav
#   inflating: /dali_datasets/test/38bc6e2c27334a9b8af3a7e1244cbfc1_6.wav
#   inflating: /dali_datasets/test/3667aa608d09487086893f3f8b0aecb2_52.wav
#   inflating: /dali_datasets/test/41adec28c9b6444baf6d38c0fa79247b_5.wav
#   inflating: /dali_datasets/test/adeeffbf18cc4c6cb3de6af56cb407cd_23.wav
#   inflating: /dali_datasets/test/e6f7c7bb2d3a465f8fb495038778c28c_2.wav
#   inflating: /dali_datasets/test/38dd5ffcbdaf440ebd53647eaf0b7b3f_9.wav
#   inflating: /dali_datasets/test/dfedd81d64c2461c83897627e0f25d25_8.wav
#   inflating: /dali_datasets/test/7a14ac26f9624922859b33caede07b07_6.wav
#   inflating: /dali_datasets/test/dd1a1d9b3fb84310ab4e559415c0aa52_15.wav
#   inflating: /dali_datasets/test/2710e4d6a4e3478fbd0ed1706840ff21_10.wav
#   inflating: /dali_datasets/test/7af9d63e524f4b0d93c841822660920d_44.wav
#   inflating: /dali_datasets/test/86fd9ce08a084c3f8016043904788f6f_24.wav
#   inflating: /dali_datasets/test/8cffd4299028493592a18e132d412e9c_28.wav
#   inflating: /dali_datasets/test/09292a9d8d6b4e008d270da087dbf51d_47.wav
#   inflating: /dali_datasets/test/86fd9ce08a084c3f8016043904788f6f_30.wav
#   inflating: /dali_datasets/test/d41b06367bcc4e3085984a6766a8f2d2_3.wav
#   inflating: /dali_datasets/test/c7b1ed7e5b1e427489a00273916376cc_0.wav
#   inflating: /dali_datasets/test/a961a043ea524ed1b5e91bf6d5bbc5db_14.wav
#   inflating: /dali_datasets/test/7ddab4ab4a0e43548f2674cbf34a2e5f_5.wav
#   inflating: /dali_datasets/test/adeeffbf18cc4c6cb3de6af56cb407cd_37.wav
#   inflating: /dali_datasets/test/57f01768c0174b109a065061bd428251_28.wav
#   inflating: /dali_datasets/test/0b632ce605a345c3b4317ed14f922354_4.wav
#   inflating: /dali_datasets/test/d7418a26f45d46f098889cc1997dddc7_23.wav
#   inflating: /dali_datasets/test/d9d748696b5949d993bdca21a49a4ebe_8.wav
#   inflating: /dali_datasets/test/3667aa608d09487086893f3f8b0aecb2_46.wav
#   inflating: /dali_datasets/test/494472a1e4f0459198e1a11b8eec1bf0_12.wav
#   inflating: /dali_datasets/test/f45833d95ffc48a092874ed9c01bcad8_3.wav
#   inflating: /dali_datasets/test/ccd577a699864e469dd77dc04de02955_31.wav
#   inflating: /dali_datasets/test/57a743bbbc7c472788d258f977c11cee_32.wav
#   inflating: /dali_datasets/test/f3bec6c19cf84f9295d5b1b112446727_22.wav
#   inflating: /dali_datasets/test/c969f501dfcd4921b49270880cee7b97_1.wav
#   inflating: /dali_datasets/test/9fe1d4ff035d43839e7556cd7293d525_30.wav
#   inflating: /dali_datasets/test/9fe1d4ff035d43839e7556cd7293d525_24.wav
#   inflating: /dali_datasets/test/6dae25f87a5f45779e0adf97b7537552_10.wav
#   inflating: /dali_datasets/test/e38385ceb34849bbb6a04576f10af45c_48.wav
#   inflating: /dali_datasets/test/06e8322a90954a028762888dfe3e70cf_46.wav
#   inflating: /dali_datasets/test/45e0ccbdf76f4060af50f95d93492755_2.wav
#   inflating: /dali_datasets/test/ae91bcda73944695b7756ddc066c3e02_6.wav
#   inflating: /dali_datasets/test/57a743bbbc7c472788d258f977c11cee_26.wav
#   inflating: /dali_datasets/test/7357de99882d49cb9a0564a8ce4d60f4_18.wav
#   inflating: /dali_datasets/test/84cfa398e56f49aa8454ceab82ed933e_7.wav
#   inflating: /dali_datasets/test/ccd577a699864e469dd77dc04de02955_25.wav
#   inflating: /dali_datasets/test/7357de99882d49cb9a0564a8ce4d60f4_30.wav
#   inflating: /dali_datasets/test/4986c16294c247f1a01dd92793a7e2b3_51.wav
#   inflating: /dali_datasets/test/5991209bcde54446a428d0d40cfd2d82_44.wav
#   inflating: /dali_datasets/test/11a0f31e81094120bf8439c597b6c7d8_33.wav
#   inflating: /dali_datasets/test/a5fd12ab0fb148ab958e7274111f1126_9.wav
#   inflating: /dali_datasets/test/4986c16294c247f1a01dd92793a7e2b3_45.wav
#   inflating: /dali_datasets/test/5991209bcde54446a428d0d40cfd2d82_50.wav
#   inflating: /dali_datasets/test/11a0f31e81094120bf8439c597b6c7d8_27.wav
#   inflating: /dali_datasets/test/07f875136c2840ccbf111373a80ba078_42.wav
#   inflating: /dali_datasets/test/9fe1d4ff035d43839e7556cd7293d525_18.wav
#   inflating: /dali_datasets/test/36113f05922b4752bf4d7b30625a1b1c_63.wav
#   inflating: /dali_datasets/test/3852f692f72e4c43bbcdb6fe021ea087_49.wav
#   inflating: /dali_datasets/test/ccd577a699864e469dd77dc04de02955_19.wav
#   inflating: /dali_datasets/test/05d128a31ad64acca530cd8f4125a423_9.wav
#   inflating: /dali_datasets/test/7357de99882d49cb9a0564a8ce4d60f4_24.wav
#   inflating: /dali_datasets/test/655baa399fb1435fb340b07a7c870fa4_13.wav
#   inflating: /dali_datasets/test/ae91bcda73944695b7756ddc066c3e02_45.wav
#   inflating: /dali_datasets/test/77f5ee6a6b3a49a294041627fe2f47c0_72.wav
#   inflating: /dali_datasets/test/2c07e4cb175d4d5b8a0e2b6291e3f917_31.wav
#   inflating: /dali_datasets/test/8eb15ad6d17f41b68009fe3848930dee_1.wav
#   inflating: /dali_datasets/test/735a95faae854e89b03a2f9f16087843_65.wav
#   inflating: /dali_datasets/test/140c5c32888d4f27af3e4fd3bf5b7250_35.wav
#   inflating: /dali_datasets/test/ef5db8d430a142d0a155093b3699acb0_3.wav
#   inflating: /dali_datasets/test/97c9e2b0ffa34f259e21d5ec0752faf6_50.wav
#   inflating: /dali_datasets/test/340a8d4b1ca945deaa14968980ce09bd_17.wav
#   inflating: /dali_datasets/test/1d257d06c8bb491ca1934516fd110b58_24.wav
#   inflating: /dali_datasets/test/f45833d95ffc48a092874ed9c01bcad8_30.wav
#   inflating: /dali_datasets/test/6871a324e73e4cbd96ef82c2d22e2736_16.wav
#   inflating: /dali_datasets/test/0348e3799c164649bc8bd0da206062f3_40.wav
#   inflating: /dali_datasets/test/33713f4d800f4eb4b2eb36a5b2461ccb_38.wav
#   inflating: /dali_datasets/test/f45833d95ffc48a092874ed9c01bcad8_24.wav
#   inflating: /dali_datasets/test/1d257d06c8bb491ca1934516fd110b58_30.wav
#   inflating: /dali_datasets/test/25276e977b304d15bd621dd63b291e15_15.wav
#   inflating: /dali_datasets/test/735a95faae854e89b03a2f9f16087843_71.wav
#   inflating: /dali_datasets/test/140c5c32888d4f27af3e4fd3bf5b7250_21.wav
#   inflating: /dali_datasets/test/84cfa398e56f49aa8454ceab82ed933e_38.wav
#   inflating: /dali_datasets/test/97c9e2b0ffa34f259e21d5ec0752faf6_44.wav
#   inflating: /dali_datasets/test/ae91bcda73944695b7756ddc066c3e02_51.wav
#   inflating: /dali_datasets/test/77f5ee6a6b3a49a294041627fe2f47c0_66.wav
#   inflating: /dali_datasets/test/07f875136c2840ccbf111373a80ba078_5.wav
#   inflating: /dali_datasets/test/2c07e4cb175d4d5b8a0e2b6291e3f917_25.wav
#   inflating: /dali_datasets/test/735a95faae854e89b03a2f9f16087843_59.wav
#   inflating: /dali_datasets/test/84cfa398e56f49aa8454ceab82ed933e_10.wav
#   inflating: /dali_datasets/test/86fd9ce08a084c3f8016043904788f6f_1.wav
#   inflating: /dali_datasets/test/e908fd35be4140d09198b407d8de54ec_44.wav
#   inflating: /dali_datasets/test/7076460d7b004306beec2fe6feddb78b_47.wav
#   inflating: /dali_datasets/test/ff348b1ede1043d8a1ab033b326f8056_20.wav
#   inflating: /dali_datasets/test/c34b9f8f9de7432d8f0f0b42e45c8269_2.wav
#   inflating: /dali_datasets/test/33713f4d800f4eb4b2eb36a5b2461ccb_10.wav
#   inflating: /dali_datasets/test/ef5db8d430a142d0a155093b3699acb0_34.wav
#   inflating: /dali_datasets/test/1d257d06c8bb491ca1934516fd110b58_18.wav
#   inflating: /dali_datasets/test/e629670ee23a4bcd8d4c85f40b296e98_4.wav
#   inflating: /dali_datasets/test/ff348b1ede1043d8a1ab033b326f8056_34.wav
#   inflating: /dali_datasets/test/ef5db8d430a142d0a155093b3699acb0_20.wav
#   inflating: /dali_datasets/test/25276e977b304d15bd621dd63b291e15_29.wav
#   inflating: /dali_datasets/test/f45833d95ffc48a092874ed9c01bcad8_18.wav
#   inflating: /dali_datasets/test/6b4369a6c8704cc4936368fc85dbfa5b_66.wav
#   inflating: /dali_datasets/test/e908fd35be4140d09198b407d8de54ec_50.wav
#   inflating: /dali_datasets/test/7076460d7b004306beec2fe6feddb78b_53.wav
#   inflating: /dali_datasets/test/2c07e4cb175d4d5b8a0e2b6291e3f917_19.wav
#   inflating: /dali_datasets/test/79c46b538c4a42b4ade34c2e78b663d5_5.wav
#   inflating: /dali_datasets/test/72df894f38944b96bee3a5041fbb34f7_17.wav
#   inflating: /dali_datasets/test/22ee1e781b6348de8db55bfdec4a1dd1_47.wav
#   inflating: /dali_datasets/test/a27f3aaa0d394a2eb6ad99bdf74d83e9_3.wav
#   inflating: /dali_datasets/test/7dba05a37342438a9ae829fd2939c50d_31.wav
#   inflating: /dali_datasets/test/135b109d487a46628e7a094f2d52f912_0.wav
#   inflating: /dali_datasets/test/c34b9f8f9de7432d8f0f0b42e45c8269_12.wav
#   inflating: /dali_datasets/test/b6de4d53fad94fe3972c6468e93a16c2_0.wav
#   inflating: /dali_datasets/test/61abf413cc244d2b94ab07b156cd72d1_15.wav
#   inflating: /dali_datasets/test/7ddab4ab4a0e43548f2674cbf34a2e5f_49.wav
#   inflating: /dali_datasets/test/289a42d903ca4b8fb5e6087a47a031a3_10.wav
#   inflating: /dali_datasets/test/53e2da93b8a84468b6f1264055a18001_4.wav
#   inflating: /dali_datasets/test/1015b75cc987411fab8cc073f7aa7cf5_1.wav
#   inflating: /dali_datasets/test/9a2d29267c484d75af6b19b14d69cab9_4.wav
#   inflating: /dali_datasets/test/b682dfe25db6411a867e3ea112f7ef85_3.wav
#   inflating: /dali_datasets/test/b60f5426792642f9a9c59717d0ec3b23_1.wav
#   inflating: /dali_datasets/test/7dba05a37342438a9ae829fd2939c50d_25.wav
#   inflating: /dali_datasets/test/22ee1e781b6348de8db55bfdec4a1dd1_53.wav
#   inflating: /dali_datasets/test/2b2a69736d924657afc12188f3eb56ee_6.wav
#   inflating: /dali_datasets/test/6dae25f87a5f45779e0adf97b7537552_5.wav
#   inflating: /dali_datasets/test/f2c034b68e5b4c889b69e55008c3fe0b_7.wav
#   inflating: /dali_datasets/test/289a42d903ca4b8fb5e6087a47a031a3_38.wav
#   inflating: /dali_datasets/test/83741a6e941c47cc9951c30583b812c9_10.wav
#   inflating: /dali_datasets/test/6f3d8aad9990437c91d3f9d77cd51f11_47.wav
#   inflating: /dali_datasets/test/61abf413cc244d2b94ab07b156cd72d1_29.wav
#   inflating: /dali_datasets/test/6f3d8aad9990437c91d3f9d77cd51f11_53.wav
#   inflating: /dali_datasets/test/7dba05a37342438a9ae829fd2939c50d_19.wav
#   inflating: /dali_datasets/test/115cb963de994aea9a3fc0e06d424703_43.wav
#   inflating: /dali_datasets/test/7a14ac26f9624922859b33caede07b07_55.wav
#   inflating: /dali_datasets/test/06e8322a90954a028762888dfe3e70cf_3.wav
#   inflating: /dali_datasets/test/ea367e89d6f245dca595ea90970f38fc_66.wav
#   inflating: /dali_datasets/test/15d6e9e88ced41dfbff38ba2f3e1d885_23.wav
#   inflating: /dali_datasets/test/498ab6a881b245479dd03b29f0fb41ae_23.wav
#   inflating: /dali_datasets/test/9a5e21d01ea94053abcc9e0c2aadab9a_5.wav
#   inflating: /dali_datasets/test/b682dfe25db6411a867e3ea112f7ef85_29.wav
#   inflating: /dali_datasets/test/dfedd81d64c2461c83897627e0f25d25_15.wav
#   inflating: /dali_datasets/test/1c901443d47a4ff3b02c5ff2db174391_4.wav
#   inflating: /dali_datasets/test/498ab6a881b245479dd03b29f0fb41ae_37.wav
#   inflating: /dali_datasets/test/f0226382730a4d339283c0e2cfaad43b_42.wav
#   inflating: /dali_datasets/test/15d6e9e88ced41dfbff38ba2f3e1d885_37.wav
#   inflating: /dali_datasets/test/5192ab7883f74bb588f65fcd1b0390e1_11.wav
#   inflating: /dali_datasets/test/568ca0f42dda4d65af3ab101931b190f_18.wav
#   inflating: /dali_datasets/test/eb7906343d6a40f1b477f0fbf607a2b9_5.wav
#   inflating: /dali_datasets/test/ea367e89d6f245dca595ea90970f38fc_72.wav
#   inflating: /dali_datasets/test/115cb963de994aea9a3fc0e06d424703_57.wav
#   inflating: /dali_datasets/test/aebd6dbeee764e1586dcadef42a51c66_29.wav
#   inflating: /dali_datasets/test/7a14ac26f9624922859b33caede07b07_41.wav
#   inflating: /dali_datasets/test/0ef5da404f744772adbcb789d3a2d9d9_36.wav
#   inflating: /dali_datasets/test/6f3d8aad9990437c91d3f9d77cd51f11_6.wav
#   inflating: /dali_datasets/test/7076460d7b004306beec2fe6feddb78b_1.wav
#   inflating: /dali_datasets/test/6b4369a6c8704cc4936368fc85dbfa5b_6.wav
#   inflating: /dali_datasets/test/7a14ac26f9624922859b33caede07b07_69.wav
#   inflating: /dali_datasets/test/c69d9213f91a40349ce570c6c8d9fdc6_51.wav
#   inflating: /dali_datasets/test/a11198cbf15842cba44fb37f81cbe6f5_45.wav
#   inflating: /dali_datasets/test/b682dfe25db6411a867e3ea112f7ef85_15.wav
#   inflating: /dali_datasets/test/0911a0b9141b4f599363f348db230113_62.wav
#   inflating: /dali_datasets/test/568ca0f42dda4d65af3ab101931b190f_30.wav
#   inflating: /dali_datasets/test/5192ab7883f74bb588f65fcd1b0390e1_39.wav
#   inflating: /dali_datasets/test/6241722644184050bb1a04a840701e54_0.wav
#   inflating: /dali_datasets/test/568ca0f42dda4d65af3ab101931b190f_24.wav
#   inflating: /dali_datasets/test/d6e3cf403653490f8366bf77cbc0f186_16.wav
#   inflating: /dali_datasets/test/dfedd81d64c2461c83897627e0f25d25_29.wav
#   inflating: /dali_datasets/test/c69d9213f91a40349ce570c6c8d9fdc6_45.wav
#   inflating: /dali_datasets/test/a11198cbf15842cba44fb37f81cbe6f5_51.wav
#   inflating: /dali_datasets/test/aebd6dbeee764e1586dcadef42a51c66_15.wav
#   inflating: /dali_datasets/test/0ef5da404f744772adbcb789d3a2d9d9_22.wav
#   inflating: /dali_datasets/test/a5fd12ab0fb148ab958e7274111f1126_31.wav
#   inflating: /dali_datasets/test/eb7906343d6a40f1b477f0fbf607a2b9_22.wav
#   inflating: /dali_datasets/test/9e75c3f388f24b21867897c32b42f779_30.wav
#   inflating: /dali_datasets/test/80ea09d8563b495aa5e651c2b4b66a8c_14.wav
#   inflating: /dali_datasets/test/ccc169aa6a884a9988718be959315781_11.wav
#   inflating: /dali_datasets/test/aebd6dbeee764e1586dcadef42a51c66_2.wav
#   inflating: /dali_datasets/test/9e75c3f388f24b21867897c32b42f779_1.wav
#   inflating: /dali_datasets/test/c6c732cc41b54a8fa558db076e8b8d93_49.wav
#   inflating: /dali_datasets/test/13ec07fd7c574af492a8370297c803ec_13.wav
#   inflating: /dali_datasets/test/fea266d6fb43438781579e75d1313063_23.wav
#   inflating: /dali_datasets/test/73972858ae3d464f9f8bf8dcd562aafd_21.wav
#   inflating: /dali_datasets/test/2710e4d6a4e3478fbd0ed1706840ff21_1.wav
#   inflating: /dali_datasets/test/8f926a264a6142edbd3bbdee06c93793_26.wav
#   inflating: /dali_datasets/test/73972858ae3d464f9f8bf8dcd562aafd_35.wav
#   inflating: /dali_datasets/test/8f926a264a6142edbd3bbdee06c93793_32.wav
#   inflating: /dali_datasets/test/afa903f29d06489189a6f77b4d1cda93_42.wav
#   inflating: /dali_datasets/test/5d6ce8b5378f41c6a9906d905c0d3c4f_3.wav
#   inflating: /dali_datasets/test/647553dfb24b4f63832722217cbc1857_28.wav
#   inflating: /dali_datasets/test/60444e5fa89e440da33bb00363985a0b_17.wav
#   inflating: /dali_datasets/test/9e75c3f388f24b21867897c32b42f779_24.wav
#   inflating: /dali_datasets/test/2a7c7dcd12e7461d8439ad06a627bfcb_48.wav
#   inflating: /dali_datasets/test/874ff998bef04d939b8b21f7434abacd_3.wav
#   inflating: /dali_datasets/test/452037efa1284176b7aa7b80a05afa95_8.wav
#   inflating: /dali_datasets/test/aa6d4f4138d340b3a286bd9b837d71de_15.wav
#   inflating: /dali_datasets/test/a5fd12ab0fb148ab958e7274111f1126_25.wav
#   inflating: /dali_datasets/test/eb7906343d6a40f1b477f0fbf607a2b9_36.wav
#   inflating: /dali_datasets/test/22cf71f0eafb4ad583c7642c803be421_32.wav
#   inflating: /dali_datasets/test/15d6e9e88ced41dfbff38ba2f3e1d885_5.wav
#   inflating: /dali_datasets/test/80ea09d8563b495aa5e651c2b4b66a8c_28.wav
#   inflating: /dali_datasets/test/45e0ccbdf76f4060af50f95d93492755_36.wav
#   inflating: /dali_datasets/test/9994eba1573e467994bea7445554d2e9_6.wav
#   inflating: /dali_datasets/test/3f4cc4b9de2545d78dffaeb8a30aff12_16.wav
#   inflating: /dali_datasets/test/45e0ccbdf76f4060af50f95d93492755_22.wav
#   inflating: /dali_datasets/test/ccc169aa6a884a9988718be959315781_6.wav
#   inflating: /dali_datasets/test/aa6d4f4138d340b3a286bd9b837d71de_29.wav
#   inflating: /dali_datasets/test/a5fd12ab0fb148ab958e7274111f1126_19.wav
#   inflating: /dali_datasets/test/cdf1f6338e5948a3acc85fd605fe4ec0_1.wav
#   inflating: /dali_datasets/test/647553dfb24b4f63832722217cbc1857_14.wav
#   inflating: /dali_datasets/test/22cf71f0eafb4ad583c7642c803be421_26.wav
#   inflating: /dali_datasets/test/cdf1f6338e5948a3acc85fd605fe4ec0_46.wav
#   inflating: /dali_datasets/test/9e75c3f388f24b21867897c32b42f779_18.wav
#   inflating: /dali_datasets/test/c6c732cc41b54a8fa558db076e8b8d93_61.wav
#   inflating: /dali_datasets/test/5a29a6f2734b4f0c9cce34a4cd165728_59.wav
#   inflating: /dali_datasets/test/9994eba1573e467994bea7445554d2e9_4.wav
#   inflating: /dali_datasets/test/8f926a264a6142edbd3bbdee06c93793_18.wav
#   inflating: /dali_datasets/test/2c701bb2320a42fab40a8ee181a1aca5_60.wav
#   inflating: /dali_datasets/test/45e0ccbdf76f4060af50f95d93492755_34.wav
#   inflating: /dali_datasets/test/cdf1f6338e5948a3acc85fd605fe4ec0_50.wav
#   inflating: /dali_datasets/test/22cf71f0eafb4ad583c7642c803be421_30.wav
#   inflating: /dali_datasets/test/15d6e9e88ced41dfbff38ba2f3e1d885_7.wav
#   inflating: /dali_datasets/test/c6c732cc41b54a8fa558db076e8b8d93_63.wav
#   inflating: /dali_datasets/test/cdf1f6338e5948a3acc85fd605fe4ec0_44.wav
#   inflating: /dali_datasets/test/60444e5fa89e440da33bb00363985a0b_29.wav
#   inflating: /dali_datasets/test/22cf71f0eafb4ad583c7642c803be421_24.wav
#   inflating: /dali_datasets/test/647553dfb24b4f63832722217cbc1857_16.wav
#   inflating: /dali_datasets/test/cdf1f6338e5948a3acc85fd605fe4ec0_3.wav
#   inflating: /dali_datasets/test/ccc169aa6a884a9988718be959315781_4.wav
#   inflating: /dali_datasets/test/ef6eb0055c5d45e8a694a621c9cf3d87_64.wav
#   inflating: /dali_datasets/test/45e0ccbdf76f4060af50f95d93492755_20.wav
#   inflating: /dali_datasets/test/3f4cc4b9de2545d78dffaeb8a30aff12_14.wav
#   inflating: /dali_datasets/test/13ec07fd7c574af492a8370297c803ec_39.wav
#   inflating: /dali_datasets/test/8f926a264a6142edbd3bbdee06c93793_24.wav
#   inflating: /dali_datasets/test/2710e4d6a4e3478fbd0ed1706840ff21_3.wav
#   inflating: /dali_datasets/test/73972858ae3d464f9f8bf8dcd562aafd_23.wav
#   inflating: /dali_datasets/test/fea266d6fb43438781579e75d1313063_21.wav
#   inflating: /dali_datasets/test/13ec07fd7c574af492a8370297c803ec_11.wav
#   inflating: /dali_datasets/test/9e75c3f388f24b21867897c32b42f779_3.wav
#   inflating: /dali_datasets/test/aebd6dbeee764e1586dcadef42a51c66_0.wav
#   inflating: /dali_datasets/test/ccc169aa6a884a9988718be959315781_13.wav
#   inflating: /dali_datasets/test/80ea09d8563b495aa5e651c2b4b66a8c_16.wav
#   inflating: /dali_datasets/test/9e75c3f388f24b21867897c32b42f779_32.wav
#   inflating: /dali_datasets/test/eb7906343d6a40f1b477f0fbf607a2b9_20.wav
#   inflating: /dali_datasets/test/a5fd12ab0fb148ab958e7274111f1126_33.wav
#   inflating: /dali_datasets/test/eb7906343d6a40f1b477f0fbf607a2b9_34.wav
#   inflating: /dali_datasets/test/a5fd12ab0fb148ab958e7274111f1126_27.wav
#   inflating: /dali_datasets/test/aa6d4f4138d340b3a286bd9b837d71de_17.wav
#   inflating: /dali_datasets/test/ef6eb0055c5d45e8a694a621c9cf3d87_58.wav
#   inflating: /dali_datasets/test/874ff998bef04d939b8b21f7434abacd_1.wav
#   inflating: /dali_datasets/test/9e75c3f388f24b21867897c32b42f779_26.wav
#   inflating: /dali_datasets/test/60444e5fa89e440da33bb00363985a0b_15.wav
#   inflating: /dali_datasets/test/22cf71f0eafb4ad583c7642c803be421_18.wav
#   inflating: /dali_datasets/test/3f4cc4b9de2545d78dffaeb8a30aff12_28.wav
#   inflating: /dali_datasets/test/fea266d6fb43438781579e75d1313063_35.wav
#   inflating: /dali_datasets/test/5d6ce8b5378f41c6a9906d905c0d3c4f_1.wav
#   inflating: /dali_datasets/test/afa903f29d06489189a6f77b4d1cda93_40.wav
#   inflating: /dali_datasets/test/6e937fd74e4542cfb62064eaaa247869_9.wav
#   inflating: /dali_datasets/test/8f926a264a6142edbd3bbdee06c93793_30.wav
#   inflating: /dali_datasets/test/2c701bb2320a42fab40a8ee181a1aca5_48.wav
#   inflating: /dali_datasets/test/73972858ae3d464f9f8bf8dcd562aafd_37.wav
#   inflating: /dali_datasets/test/568ca0f42dda4d65af3ab101931b190f_32.wav
#   inflating: /dali_datasets/test/6241722644184050bb1a04a840701e54_2.wav
#   inflating: /dali_datasets/test/0911a0b9141b4f599363f348db230113_60.wav
#   inflating: /dali_datasets/test/b682dfe25db6411a867e3ea112f7ef85_17.wav
#   inflating: /dali_datasets/test/a11198cbf15842cba44fb37f81cbe6f5_47.wav
#   inflating: /dali_datasets/test/c69d9213f91a40349ce570c6c8d9fdc6_53.wav
#   inflating: /dali_datasets/test/2094f07bd8534ae5b4e4fa5d1a1251c4_18.wav
#   inflating: /dali_datasets/test/6b4369a6c8704cc4936368fc85dbfa5b_4.wav
#   inflating: /dali_datasets/test/7076460d7b004306beec2fe6feddb78b_3.wav
#   inflating: /dali_datasets/test/6f3d8aad9990437c91d3f9d77cd51f11_4.wav
#   inflating: /dali_datasets/test/0ef5da404f744772adbcb789d3a2d9d9_34.wav
#   inflating: /dali_datasets/test/ea367e89d6f245dca595ea90970f38fc_58.wav
#   inflating: /dali_datasets/test/06476d0a94a1434d8247900394d1fece_49.wav
#   inflating: /dali_datasets/test/0ef5da404f744772adbcb789d3a2d9d9_20.wav
#   inflating: /dali_datasets/test/aebd6dbeee764e1586dcadef42a51c66_17.wav
#   inflating: /dali_datasets/test/a11198cbf15842cba44fb37f81cbe6f5_53.wav
#   inflating: /dali_datasets/test/c69d9213f91a40349ce570c6c8d9fdc6_47.wav
#   inflating: /dali_datasets/test/d6e3cf403653490f8366bf77cbc0f186_14.wav
#   inflating: /dali_datasets/test/568ca0f42dda4d65af3ab101931b190f_26.wav
#   inflating: /dali_datasets/test/9a5e21d01ea94053abcc9e0c2aadab9a_7.wav
#   inflating: /dali_datasets/test/498ab6a881b245479dd03b29f0fb41ae_21.wav
#   inflating: /dali_datasets/test/15d6e9e88ced41dfbff38ba2f3e1d885_21.wav
#   inflating: /dali_datasets/test/ea367e89d6f245dca595ea90970f38fc_64.wav
#   inflating: /dali_datasets/test/06e8322a90954a028762888dfe3e70cf_1.wav
#   inflating: /dali_datasets/test/7a14ac26f9624922859b33caede07b07_57.wav
#   inflating: /dali_datasets/test/115cb963de994aea9a3fc0e06d424703_41.wav
#   inflating: /dali_datasets/test/7a14ac26f9624922859b33caede07b07_43.wav
#   inflating: /dali_datasets/test/115cb963de994aea9a3fc0e06d424703_55.wav
#   inflating: /dali_datasets/test/ff33ea7be69e46e4bf154c1d6f3ae45b_9.wav
#   inflating: /dali_datasets/test/ea367e89d6f245dca595ea90970f38fc_70.wav
#   inflating: /dali_datasets/test/eb7906343d6a40f1b477f0fbf607a2b9_7.wav
#   inflating: /dali_datasets/test/5192ab7883f74bb588f65fcd1b0390e1_13.wav
#   inflating: /dali_datasets/test/d6e3cf403653490f8366bf77cbc0f186_28.wav
#   inflating: /dali_datasets/test/15d6e9e88ced41dfbff38ba2f3e1d885_35.wav
#   inflating: /dali_datasets/test/0911a0b9141b4f599363f348db230113_48.wav
#   inflating: /dali_datasets/test/f0226382730a4d339283c0e2cfaad43b_40.wav
#   inflating: /dali_datasets/test/dfedd81d64c2461c83897627e0f25d25_17.wav
#   inflating: /dali_datasets/test/498ab6a881b245479dd03b29f0fb41ae_35.wav
#   inflating: /dali_datasets/test/1c901443d47a4ff3b02c5ff2db174391_6.wav
#   inflating: /dali_datasets/test/6f3d8aad9990437c91d3f9d77cd51f11_45.wav
#   inflating: /dali_datasets/test/83741a6e941c47cc9951c30583b812c9_12.wav
#   inflating: /dali_datasets/test/f2c034b68e5b4c889b69e55008c3fe0b_5.wav
#   inflating: /dali_datasets/test/6dae25f87a5f45779e0adf97b7537552_7.wav
#   inflating: /dali_datasets/test/2b2a69736d924657afc12188f3eb56ee_4.wav
#   inflating: /dali_datasets/test/6f3d8aad9990437c91d3f9d77cd51f11_51.wav
#   inflating: /dali_datasets/test/c34b9f8f9de7432d8f0f0b42e45c8269_38.wav
#   inflating: /dali_datasets/test/b6de4d53fad94fe3972c6468e93a16c2_2.wav
#   inflating: /dali_datasets/test/61abf413cc244d2b94ab07b156cd72d1_17.wav
#   inflating: /dali_datasets/test/c34b9f8f9de7432d8f0f0b42e45c8269_10.wav
#   inflating: /dali_datasets/test/135b109d487a46628e7a094f2d52f912_2.wav
#   inflating: /dali_datasets/test/7dba05a37342438a9ae829fd2939c50d_33.wav
#   inflating: /dali_datasets/test/a27f3aaa0d394a2eb6ad99bdf74d83e9_1.wav
#   inflating: /dali_datasets/test/adeeffbf18cc4c6cb3de6af56cb407cd_9.wav
#   inflating: /dali_datasets/test/22ee1e781b6348de8db55bfdec4a1dd1_45.wav
#   inflating: /dali_datasets/test/22ee1e781b6348de8db55bfdec4a1dd1_51.wav
#   inflating: /dali_datasets/test/f3bec6c19cf84f9295d5b1b112446727_8.wav
#   inflating: /dali_datasets/test/7dba05a37342438a9ae829fd2939c50d_27.wav
#   inflating: /dali_datasets/test/b60f5426792642f9a9c59717d0ec3b23_3.wav
#   inflating: /dali_datasets/test/9a2d29267c484d75af6b19b14d69cab9_6.wav
#   inflating: /dali_datasets/test/1015b75cc987411fab8cc073f7aa7cf5_3.wav
#   inflating: /dali_datasets/test/b682dfe25db6411a867e3ea112f7ef85_1.wav
#   inflating: /dali_datasets/test/53e2da93b8a84468b6f1264055a18001_6.wav
#   inflating: /dali_datasets/test/289a42d903ca4b8fb5e6087a47a031a3_12.wav
#   inflating: /dali_datasets/test/4b7a3ce58693448e89b44e21b2a16e42_18.wav
#   inflating: /dali_datasets/test/340a8d4b1ca945deaa14968980ce09bd_29.wav
#   inflating: /dali_datasets/test/33713f4d800f4eb4b2eb36a5b2461ccb_12.wav
#   inflating: /dali_datasets/test/ef5db8d430a142d0a155093b3699acb0_36.wav
#   inflating: /dali_datasets/test/c34b9f8f9de7432d8f0f0b42e45c8269_0.wav
#   inflating: /dali_datasets/test/ff348b1ede1043d8a1ab033b326f8056_22.wav
#   inflating: /dali_datasets/test/7076460d7b004306beec2fe6feddb78b_45.wav
#   inflating: /dali_datasets/test/6b4369a6c8704cc4936368fc85dbfa5b_70.wav
#   inflating: /dali_datasets/test/86fd9ce08a084c3f8016043904788f6f_3.wav
#   inflating: /dali_datasets/test/e908fd35be4140d09198b407d8de54ec_46.wav
#   inflating: /dali_datasets/test/84cfa398e56f49aa8454ceab82ed933e_12.wav
#   inflating: /dali_datasets/test/72df894f38944b96bee3a5041fbb34f7_15.wav
#   inflating: /dali_datasets/test/a1f95acf37684dbda26a0fd9d7e99f29_9.wav
#   inflating: /dali_datasets/test/79c46b538c4a42b4ade34c2e78b663d5_7.wav
#   inflating: /dali_datasets/test/7076460d7b004306beec2fe6feddb78b_51.wav
#   inflating: /dali_datasets/test/77f5ee6a6b3a49a294041627fe2f47c0_58.wav
#   inflating: /dali_datasets/test/6b4369a6c8704cc4936368fc85dbfa5b_64.wav
#   inflating: /dali_datasets/test/e908fd35be4140d09198b407d8de54ec_52.wav
#   inflating: /dali_datasets/test/ef5db8d430a142d0a155093b3699acb0_22.wav
#   inflating: /dali_datasets/test/ff348b1ede1043d8a1ab033b326f8056_36.wav
#   inflating: /dali_datasets/test/e629670ee23a4bcd8d4c85f40b296e98_6.wav
#   inflating: /dali_datasets/test/6871a324e73e4cbd96ef82c2d22e2736_28.wav
#   inflating: /dali_datasets/test/f45833d95ffc48a092874ed9c01bcad8_32.wav
#   inflating: /dali_datasets/test/1d257d06c8bb491ca1934516fd110b58_26.wav
#   inflating: /dali_datasets/test/5ee5d7662fcb42a683f64490dec96dcf_8.wav
#   inflating: /dali_datasets/test/4b7a3ce58693448e89b44e21b2a16e42_24.wav
#   inflating: /dali_datasets/test/340a8d4b1ca945deaa14968980ce09bd_15.wav
#   inflating: /dali_datasets/test/97c9e2b0ffa34f259e21d5ec0752faf6_52.wav
#   inflating: /dali_datasets/test/ef5db8d430a142d0a155093b3699acb0_1.wav
#   inflating: /dali_datasets/test/140c5c32888d4f27af3e4fd3bf5b7250_37.wav
#   inflating: /dali_datasets/test/735a95faae854e89b03a2f9f16087843_67.wav
#   inflating: /dali_datasets/test/2c07e4cb175d4d5b8a0e2b6291e3f917_33.wav
#   inflating: /dali_datasets/test/8eb15ad6d17f41b68009fe3848930dee_3.wav
#   inflating: /dali_datasets/test/77f5ee6a6b3a49a294041627fe2f47c0_70.wav
#   inflating: /dali_datasets/test/ae91bcda73944695b7756ddc066c3e02_47.wav
#   inflating: /dali_datasets/test/655baa399fb1435fb340b07a7c870fa4_11.wav
#   inflating: /dali_datasets/test/2c07e4cb175d4d5b8a0e2b6291e3f917_27.wav
#   inflating: /dali_datasets/test/07f875136c2840ccbf111373a80ba078_7.wav
#   inflating: /dali_datasets/test/77f5ee6a6b3a49a294041627fe2f47c0_64.wav
#   inflating: /dali_datasets/test/ae91bcda73944695b7756ddc066c3e02_53.wav
#   inflating: /dali_datasets/test/6b4369a6c8704cc4936368fc85dbfa5b_58.wav
#   inflating: /dali_datasets/test/72df894f38944b96bee3a5041fbb34f7_29.wav
#   inflating: /dali_datasets/test/97c9e2b0ffa34f259e21d5ec0752faf6_46.wav
#   inflating: /dali_datasets/test/140c5c32888d4f27af3e4fd3bf5b7250_23.wav
#   inflating: /dali_datasets/test/1d257d06c8bb491ca1934516fd110b58_32.wav
#   inflating: /dali_datasets/test/f45833d95ffc48a092874ed9c01bcad8_26.wav
#   inflating: /dali_datasets/test/25276e977b304d15bd621dd63b291e15_17.wav
#   inflating: /dali_datasets/test/0348e3799c164649bc8bd0da206062f3_42.wav
#   inflating: /dali_datasets/test/6871a324e73e4cbd96ef82c2d22e2736_14.wav
#   inflating: /dali_datasets/test/11a0f31e81094120bf8439c597b6c7d8_31.wav
#   inflating: /dali_datasets/test/e6f7c7bb2d3a465f8fb495038778c28c_45.wav
#   inflating: /dali_datasets/test/4986c16294c247f1a01dd92793a7e2b3_53.wav
#   inflating: /dali_datasets/test/5991209bcde54446a428d0d40cfd2d82_46.wav
#   inflating: /dali_datasets/test/7357de99882d49cb9a0564a8ce4d60f4_32.wav
#   inflating: /dali_datasets/test/7357de99882d49cb9a0564a8ce4d60f4_26.wav
#   inflating: /dali_datasets/test/57a743bbbc7c472788d258f977c11cee_18.wav
#   inflating: /dali_datasets/test/36113f05922b4752bf4d7b30625a1b1c_61.wav
#   inflating: /dali_datasets/test/07f875136c2840ccbf111373a80ba078_40.wav
#   inflating: /dali_datasets/test/11a0f31e81094120bf8439c597b6c7d8_25.wav
#   inflating: /dali_datasets/test/4986c16294c247f1a01dd92793a7e2b3_47.wav
#   inflating: /dali_datasets/test/5991209bcde54446a428d0d40cfd2d82_52.wav
#   inflating: /dali_datasets/test/36113f05922b4752bf4d7b30625a1b1c_49.wav
#   inflating: /dali_datasets/test/9fe1d4ff035d43839e7556cd7293d525_32.wav
#   inflating: /dali_datasets/test/c969f501dfcd4921b49270880cee7b97_3.wav
#   inflating: /dali_datasets/test/f3bec6c19cf84f9295d5b1b112446727_20.wav
#   inflating: /dali_datasets/test/38dd5ffcbdaf440ebd53647eaf0b7b3f_15.wav
#   inflating: /dali_datasets/test/57a743bbbc7c472788d258f977c11cee_30.wav
#   inflating: /dali_datasets/test/2912905665674a27bb0f2c6fb3ca635e_8.wav
#   inflating: /dali_datasets/test/289a42d903ca4b8fb5e6087a47a031a3_8.wav
#   inflating: /dali_datasets/test/ccd577a699864e469dd77dc04de02955_33.wav
# ...
#   inflating: /dali_datasets/test/11a0f31e81094120bf8439c597b6c7d8_9.wav
#   inflating: /dali_datasets/test/452037efa1284176b7aa7b80a05afa95_41.wav
#   inflating: /dali_datasets/test/9fe1d4ff035d43839e7556cd7293d525_2.wav
#   inflating: /dali_datasets/test/b0c1c41a5a024f47ae1eca7a8b5ca59b_1.wav
#   inflating: /dali_datasets/test/a8762df0f6724497b8d9ccc1308cee25_22.wav
#   inflating: /dali_datasets/test/72df894f38944b96bee3a5041fbb34f7_4.wav
#   inflating: /dali_datasets/test/a8762df0f6724497b8d9ccc1308cee25_36.wav
#   inflating: /dali_datasets/test/d9d748696b5949d993bdca21a49a4ebe_28.wav
#   inflating: /dali_datasets/test/25276e977b304d15bd621dd63b291e15_7.wav
#   inflating: /dali_datasets/test/0cf0e93e4baa4e4fb9ce69b3555ff9a3_10.wav
#   inflating: /dali_datasets/test/1583c8f1dfa448d6a3392c82e25b9657_28.wav
#   inflating: /dali_datasets/test/2fd0fbfa0ff34734a0beb4730c5a761a_51.wav
#   inflating: /dali_datasets/test/b6de4d53fad94fe3972c6468e93a16c2_45.wav
#   inflating: /dali_datasets/test/2912905665674a27bb0f2c6fb3ca635e_25.wav
#   inflating: /dali_datasets/test/1785a186119f434ba37583887326b028_17.wav
#   inflating: /dali_datasets/test/13ec07fd7c574af492a8370297c803ec_7.wav
#   inflating: /dali_datasets/test/313732b590f0448da98acb954e365062_17.wav
#   inflating: /dali_datasets/test/63543c65e84041dcbb5a9e1eb900d236_0.wav
#   inflating: /dali_datasets/test/f0226382730a4d339283c0e2cfaad43b_7.wav
#   inflating: /dali_datasets/test/6e937fd74e4542cfb62064eaaa247869_39.wav
#   inflating: /dali_datasets/test/e6f7c7bb2d3a465f8fb495038778c28c_21.wav
#   inflating: /dali_datasets/test/5991209bcde54446a428d0d40cfd2d82_22.wav
#   inflating: /dali_datasets/test/4986c16294c247f1a01dd92793a7e2b3_37.wav
#   inflating: /dali_datasets/test/9a2d29267c484d75af6b19b14d69cab9_19.wav
#   inflating: /dali_datasets/test/dd1a1d9b3fb84310ab4e559415c0aa52_9.wav
#   inflating: /dali_datasets/test/07f875136c2840ccbf111373a80ba078_30.wav
#   inflating: /dali_datasets/test/36113f05922b4752bf4d7b30625a1b1c_11.wav
#   inflating: /dali_datasets/test/97349fc35f414864ab080f7c78e3f51e_11.wav
#   inflating: /dali_datasets/test/07f875136c2840ccbf111373a80ba078_24.wav
#   inflating: /dali_datasets/test/36113f05922b4752bf4d7b30625a1b1c_1.wav
#   inflating: /dali_datasets/test/e38385ceb34849bbb6a04576f10af45c_12.wav
#   inflating: /dali_datasets/test/6ebfa46300b347ecb12389add06e6d28_8.wav
#   inflating: /dali_datasets/test/ae62daf4c9b34bdba090bc5a1906fd77_19.wav
#   inflating: /dali_datasets/test/11a0f31e81094120bf8439c597b6c7d8_41.wav
#   inflating: /dali_datasets/test/e6f7c7bb2d3a465f8fb495038778c28c_35.wav
#   inflating: /dali_datasets/test/e38385ceb34849bbb6a04576f10af45c_2.wav
#   inflating: /dali_datasets/test/5991209bcde54446a428d0d40cfd2d82_36.wav
#   inflating: /dali_datasets/test/4986c16294c247f1a01dd92793a7e2b3_23.wav
#   inflating: /dali_datasets/test/7357de99882d49cb9a0564a8ce4d60f4_42.wav
#   inflating: /dali_datasets/test/3f4cc4b9de2545d78dffaeb8a30aff12_5.wav
#   inflating: /dali_datasets/test/2912905665674a27bb0f2c6fb3ca635e_19.wav
#   inflating: /dali_datasets/test/9a2d29267c484d75af6b19b14d69cab9_25.wav
#   inflating: /dali_datasets/test/15c1f27eaaa64f5fb9e3cfebff8d2a91_35.wav
#   inflating: /dali_datasets/test/9fe1d4ff035d43839e7556cd7293d525_56.wav
#   inflating: /dali_datasets/test/97349fc35f414864ab080f7c78e3f51e_39.wav
#   inflating: /dali_datasets/test/06e8322a90954a028762888dfe3e70cf_34.wav
#   inflating: /dali_datasets/test/7a1642003f574713a6e25e5ee549fce6_13.wav
#   inflating: /dali_datasets/test/498ab6a881b245479dd03b29f0fb41ae_0.wav
#   inflating: /dali_datasets/test/06e8322a90954a028762888dfe3e70cf_20.wav
#   inflating: /dali_datasets/test/6e937fd74e4542cfb62064eaaa247869_11.wav
#   inflating: /dali_datasets/test/15c1f27eaaa64f5fb9e3cfebff8d2a91_21.wav
#   inflating: /dali_datasets/test/9a2d29267c484d75af6b19b14d69cab9_31.wav
#   inflating: /dali_datasets/test/07f875136c2840ccbf111373a80ba078_18.wav
#   inflating: /dali_datasets/test/9fe1d4ff035d43839e7556cd7293d525_42.wav
#   inflating: /dali_datasets/test/36113f05922b4752bf4d7b30625a1b1c_39.wav
#   inflating: /dali_datasets/test/b32c14c66b2545d2b087db7b36aa1d0e_12.wav
#   inflating: /dali_datasets/test/e61d7f0bf9ad4947885ca6e0b664b23d_3.wav
#   inflating: /dali_datasets/test/3852f692f72e4c43bbcdb6fe021ea087_13.wav
#   inflating: /dali_datasets/test/b3163934970d41509306b8870763aad8_21.wav
#   inflating: /dali_datasets/test/ccd577a699864e469dd77dc04de02955_43.wav
#   inflating: /dali_datasets/test/6241722644184050bb1a04a840701e54_11.wav
#   inflating: /dali_datasets/test/57a743bbbc7c472788d258f977c11cee_40.wav
#   inflating: /dali_datasets/test/77f5ee6a6b3a49a294041627fe2f47c0_28.wav
#   inflating: /dali_datasets/test/e908fd35be4140d09198b407d8de54ec_22.wav
#   inflating: /dali_datasets/test/6b4369a6c8704cc4936368fc85dbfa5b_14.wav
#   inflating: /dali_datasets/test/7076460d7b004306beec2fe6feddb78b_21.wav
#   inflating: /dali_datasets/test/72df894f38944b96bee3a5041fbb34f7_65.wav
#   inflating: /dali_datasets/test/e908fd35be4140d09198b407d8de54ec_2.wav
#   inflating: /dali_datasets/test/97349fc35f414864ab080f7c78e3f51e_1.wav
#   inflating: /dali_datasets/test/ff348b1ede1043d8a1ab033b326f8056_46.wav
#   inflating: /dali_datasets/test/ef5db8d430a142d0a155093b3699acb0_52.wav
#   inflating: /dali_datasets/test/ff348b1ede1043d8a1ab033b326f8056_52.wav
#   inflating: /dali_datasets/test/7dba05a37342438a9ae829fd2939c50d_0.wav
#   inflating: /dali_datasets/test/ef5db8d430a142d0a155093b3699acb0_46.wav
#   inflating: /dali_datasets/test/647553dfb24b4f63832722217cbc1857_1.wav
#   inflating: /dali_datasets/test/33713f4d800f4eb4b2eb36a5b2461ccb_62.wav
#   inflating: /dali_datasets/test/05d128a31ad64acca530cd8f4125a423_17.wav
#   inflating: /dali_datasets/test/8bb8c6bb7be24aee8beac52b68525604_0.wav
#   inflating: /dali_datasets/test/0e51f03136de44339626fd6af72ee646_7.wav
#   inflating: /dali_datasets/test/72df894f38944b96bee3a5041fbb34f7_71.wav
#   inflating: /dali_datasets/test/e908fd35be4140d09198b407d8de54ec_36.wav
#   inflating: /dali_datasets/test/7076460d7b004306beec2fe6feddb78b_35.wav
#   inflating: /dali_datasets/test/6c180ba4d4314ee2b8dbf3b8ff3e6597_7.wav
#   inflating: /dali_datasets/test/6ebfa46300b347ecb12389add06e6d28_11.wav
#   inflating: /dali_datasets/test/44a2455abc0e4fb397a396d2cd1ebeb9_17.wav
#   inflating: /dali_datasets/test/140c5c32888d4f27af3e4fd3bf5b7250_53.wav
#   inflating: /dali_datasets/test/97c9e2b0ffa34f259e21d5ec0752faf6_36.wav
#   inflating: /dali_datasets/test/72df894f38944b96bee3a5041fbb34f7_59.wav
#   inflating: /dali_datasets/test/77f5ee6a6b3a49a294041627fe2f47c0_14.wav
#   inflating: /dali_datasets/test/6b4369a6c8704cc4936368fc85dbfa5b_28.wav
#   inflating: /dali_datasets/test/a27f3aaa0d394a2eb6ad99bdf74d83e9_33.wav
#   inflating: /dali_datasets/test/ae91bcda73944695b7756ddc066c3e02_23.wav
#   inflating: /dali_datasets/test/6ebfa46300b347ecb12389add06e6d28_39.wav
#   inflating: /dali_datasets/test/d41b06367bcc4e3085984a6766a8f2d2_35.wav
#   inflating: /dali_datasets/test/2c07e4cb175d4d5b8a0e2b6291e3f917_57.wav
#   inflating: /dali_datasets/test/0348e3799c164649bc8bd0da206062f3_32.wav
#   inflating: /dali_datasets/test/25276e977b304d15bd621dd63b291e15_67.wav
#   inflating: /dali_datasets/test/1d257d06c8bb491ca1934516fd110b58_42.wav
#   inflating: /dali_datasets/test/f45833d95ffc48a092874ed9c01bcad8_56.wav
#   inflating: /dali_datasets/test/f97b5ce17a7645cfb9e90f365c622d44_4.wav
#   inflating: /dali_datasets/test/73972858ae3d464f9f8bf8dcd562aafd_4.wav
#   inflating: /dali_datasets/test/0348e3799c164649bc8bd0da206062f3_26.wav
#   inflating: /dali_datasets/test/25276e977b304d15bd621dd63b291e15_73.wav
#   inflating: /dali_datasets/test/f45833d95ffc48a092874ed9c01bcad8_42.wav
#   inflating: /dali_datasets/test/fe6e0b5a8b4a42358e5001a5b2f10daa_16.wav
#   inflating: /dali_datasets/test/ae91bcda73944695b7756ddc066c3e02_37.wav
#   inflating: /dali_datasets/test/a27f3aaa0d394a2eb6ad99bdf74d83e9_27.wav
#   inflating: /dali_datasets/test/d41b06367bcc4e3085984a6766a8f2d2_21.wav
#   inflating: /dali_datasets/test/2c07e4cb175d4d5b8a0e2b6291e3f917_43.wav
#   inflating: /dali_datasets/test/140c5c32888d4f27af3e4fd3bf5b7250_47.wav
#   inflating: /dali_datasets/test/735a95faae854e89b03a2f9f16087843_17.wav
#   inflating: /dali_datasets/test/b4759e8b2f5d4f3d88ef8111c0c3cfea_14.wav
#   inflating: /dali_datasets/test/97c9e2b0ffa34f259e21d5ec0752faf6_22.wav
#   inflating: /dali_datasets/test/a59e44a4c910443a87f068b177200fdc_3.wav
#   inflating: /dali_datasets/test/ac0279efad294261b4c7dc0b86eaaec5_5.wav
#   inflating: /dali_datasets/test/463f5b79b3f1459887c96c368b16c9c0_5.wav
#   inflating: /dali_datasets/test/5f8ea2abaad54d8e890fadcc7750710f_7.wav
#   inflating: /dali_datasets/test/c34b9f8f9de7432d8f0f0b42e45c8269_48.wav
#   inflating: /dali_datasets/test/6f3d8aad9990437c91d3f9d77cd51f11_21.wav
#   inflating: /dali_datasets/test/7ddab4ab4a0e43548f2674cbf34a2e5f_13.wav
#   inflating: /dali_datasets/test/583b1d527ce941b883aef122813baf3c_15.wav
#   inflating: /dali_datasets/test/6f3d8aad9990437c91d3f9d77cd51f11_35.wav
#   inflating: /dali_datasets/test/115cb963de994aea9a3fc0e06d424703_2.wav
#   inflating: /dali_datasets/test/40e95f7040dc406f9387e3ba6352d630_16.wav
#   inflating: /dali_datasets/test/22ee1e781b6348de8db55bfdec4a1dd1_21.wav
#   inflating: /dali_datasets/test/134fa78a3d4a462299db018f0444ce26_32.wav
#   inflating: /dali_datasets/test/289a42d903ca4b8fb5e6087a47a031a3_62.wav
#   inflating: /dali_datasets/test/463f5b79b3f1459887c96c368b16c9c0_26.wav
#   inflating: /dali_datasets/test/61abf413cc244d2b94ab07b156cd72d1_67.wav
#   inflating: /dali_datasets/test/c34b9f8f9de7432d8f0f0b42e45c8269_60.wav
#   inflating: /dali_datasets/test/22ee1e781b6348de8db55bfdec4a1dd1_35.wav
#   inflating: /dali_datasets/test/134fa78a3d4a462299db018f0444ce26_26.wav
#   inflating: /dali_datasets/test/215a11a438ce4963be16212d71d68aaa_6.wav
#   inflating: /dali_datasets/test/7dba05a37342438a9ae829fd2939c50d_43.wav
#   inflating: /dali_datasets/test/115cb963de994aea9a3fc0e06d424703_19.wav
#   inflating: /dali_datasets/test/33713f4d800f4eb4b2eb36a5b2461ccb_9.wav
#   inflating: /dali_datasets/test/140c5c32888d4f27af3e4fd3bf5b7250_4.wav
#   inflating: /dali_datasets/test/568ca0f42dda4d65af3ab101931b190f_56.wav
#   inflating: /dali_datasets/test/607bb216fd9c49f88604be23bb3bc87c_10.wav
#   inflating: /dali_datasets/test/c69d9213f91a40349ce570c6c8d9fdc6_37.wav
#   inflating: /dali_datasets/test/a11198cbf15842cba44fb37f81cbe6f5_23.wav
#   inflating: /dali_datasets/test/135b109d487a46628e7a094f2d52f912_25.wav
#   inflating: /dali_datasets/test/f0226382730a4d339283c0e2cfaad43b_18.wav
#   inflating: /dali_datasets/test/c69d9213f91a40349ce570c6c8d9fdc6_23.wav
#   inflating: /dali_datasets/test/0911a0b9141b4f599363f348db230113_10.wav
#   inflating: /dali_datasets/test/c969f501dfcd4921b49270880cee7b97_28.wav
#   inflating: /dali_datasets/test/a11198cbf15842cba44fb37f81cbe6f5_37.wav
#   inflating: /dali_datasets/test/568ca0f42dda4d65af3ab101931b190f_42.wav
#   inflating: /dali_datasets/test/ea367e89d6f245dca595ea90970f38fc_28.wav
#   inflating: /dali_datasets/test/06476d0a94a1434d8247900394d1fece_39.wav
#   inflating: /dali_datasets/test/1015b75cc987411fab8cc073f7aa7cf5_38.wav
#   inflating: /dali_datasets/test/c7b1ed7e5b1e427489a00273916376cc_13.wav
#   inflating: /dali_datasets/test/06476d0a94a1434d8247900394d1fece_11.wav
#   inflating: /dali_datasets/test/af358461b75342a8a87f92912634a7d8_9.wav
#   inflating: /dali_datasets/test/134fa78a3d4a462299db018f0444ce26_2.wav
#   inflating: /dali_datasets/test/115cb963de994aea9a3fc0e06d424703_25.wav
#   inflating: /dali_datasets/test/2c07e4cb175d4d5b8a0e2b6291e3f917_2.wav
#   inflating: /dali_datasets/test/1015b75cc987411fab8cc073f7aa7cf5_10.wav
#   inflating: /dali_datasets/test/7a14ac26f9624922859b33caede07b07_33.wav
#   inflating: /dali_datasets/test/f0226382730a4d339283c0e2cfaad43b_30.wav
#   inflating: /dali_datasets/test/498ab6a881b245479dd03b29f0fb41ae_45.wav
#   inflating: /dali_datasets/test/0911a0b9141b4f599363f348db230113_38.wav
#   inflating: /dali_datasets/test/5192ab7883f74bb588f65fcd1b0390e1_63.wav
#   inflating: /dali_datasets/test/15d6e9e88ced41dfbff38ba2f3e1d885_45.wav
#   inflating: /dali_datasets/test/dc0cd0d4ec64447e894540fe4a0a01f5_13.wav
#   inflating: /dali_datasets/test/15d6e9e88ced41dfbff38ba2f3e1d885_51.wav
#   inflating: /dali_datasets/test/f0226382730a4d339283c0e2cfaad43b_24.wav
#   inflating: /dali_datasets/test/135b109d487a46628e7a094f2d52f912_19.wav
#   inflating: /dali_datasets/test/c969f501dfcd4921b49270880cee7b97_14.wav
#   inflating: /dali_datasets/test/115cb963de994aea9a3fc0e06d424703_31.wav
#   inflating: /dali_datasets/test/7a14ac26f9624922859b33caede07b07_27.wav
#   inflating: /dali_datasets/test/ea367e89d6f245dca595ea90970f38fc_14.wav
#   inflating: /dali_datasets/test/b4759e8b2f5d4f3d88ef8111c0c3cfea_5.wav
#   inflating: /dali_datasets/test/3667aa608d09487086893f3f8b0aecb2_1.wav
#   inflating: /dali_datasets/test/ef6eb0055c5d45e8a694a621c9cf3d87_14.wav
#   inflating: /dali_datasets/test/8d7f9342cf644e8797f4d7d0402a75bd_35.wav
#   inflating: /dali_datasets/test/1c901443d47a4ff3b02c5ff2db174391_28.wav
#   inflating: /dali_datasets/test/cdf1f6338e5948a3acc85fd605fe4ec0_34.wav
#   inflating: /dali_datasets/test/c6c732cc41b54a8fa558db076e8b8d93_13.wav
#   inflating: /dali_datasets/test/13ec07fd7c574af492a8370297c803ec_49.wav
#   inflating: /dali_datasets/test/b3639d60a49e45578a201d910f36c44c_2.wav
#   inflating: /dali_datasets/test/9a5e21d01ea94053abcc9e0c2aadab9a_29.wav
#   inflating: /dali_datasets/test/3f4cc4b9de2545d78dffaeb8a30aff12_64.wav
#   inflating: /dali_datasets/test/1c6112908256403faa9812bb7930a8a1_26.wav
#   inflating: /dali_datasets/test/2c701bb2320a42fab40a8ee181a1aca5_10.wav
#   inflating: /dali_datasets/test/afa903f29d06489189a6f77b4d1cda93_18.wav
#   inflating: /dali_datasets/test/4789ae2083ac430b8628beb5f1fd6424_11.wav
#   inflating: /dali_datasets/test/5a29a6f2734b4f0c9cce34a4cd165728_29.wav
#   inflating: /dali_datasets/test/3f4cc4b9de2545d78dffaeb8a30aff12_70.wav
#   inflating: /dali_datasets/test/2a7c7dcd12e7461d8439ad06a627bfcb_12.wav
#   inflating: /dali_datasets/test/cdf1f6338e5948a3acc85fd605fe4ec0_20.wav
#   inflating: /dali_datasets/test/22cf71f0eafb4ad583c7642c803be421_40.wav
#   inflating: /dali_datasets/test/8d7f9342cf644e8797f4d7d0402a75bd_21.wav
#   inflating: /dali_datasets/test/06476d0a94a1434d8247900394d1fece_9.wav
#   inflating: /dali_datasets/test/1c901443d47a4ff3b02c5ff2db174391_14.wav
#   inflating: /dali_datasets/test/9e75c3f388f24b21867897c32b42f779_56.wav
#   inflating: /dali_datasets/test/ef6eb0055c5d45e8a694a621c9cf3d87_28.wav
#   inflating: /dali_datasets/test/eb7906343d6a40f1b477f0fbf607a2b9_44.wav
#   inflating: /dali_datasets/test/2c701bb2320a42fab40a8ee181a1aca5_38.wav
#   inflating: /dali_datasets/test/4cec9fa30b0c4ed78f4f99b63a9866a6_9.wav
#   inflating: /dali_datasets/test/aa6d4f4138d340b3a286bd9b837d71de_2.wav
#   inflating: /dali_datasets/test/afa903f29d06489189a6f77b4d1cda93_30.wav
#   inflating: /dali_datasets/test/8f926a264a6142edbd3bbdee06c93793_40.wav
#   inflating: /dali_datasets/test/9a5e21d01ea94053abcc9e0c2aadab9a_15.wav
#   inflating: /dali_datasets/test/c69d9213f91a40349ce570c6c8d9fdc6_3.wav
#   inflating: /dali_datasets/test/3f4cc4b9de2545d78dffaeb8a30aff12_58.wav
#   inflating: /dali_datasets/test/5a29a6f2734b4f0c9cce34a4cd165728_15.wav
#   inflating: /dali_datasets/test/afa903f29d06489189a6f77b4d1cda93_24.wav
#   inflating: /dali_datasets/test/8f926a264a6142edbd3bbdee06c93793_54.wav
#   inflating: /dali_datasets/test/a5fd12ab0fb148ab958e7274111f1126_43.wav
#   inflating: /dali_datasets/test/15c1f27eaaa64f5fb9e3cfebff8d2a91_0.wav
#   inflating: /dali_datasets/test/eb7906343d6a40f1b477f0fbf607a2b9_50.wav
#   inflating: /dali_datasets/test/9e75c3f388f24b21867897c32b42f779_42.wav

# %%
# !pip install transformers==4.39.1
# !pip install accelerate==0.28.0
# !pip install evaluate
# !pip install torchaudio
# !pip install flashlight-text
# !pip install jiwer
# Out:
# Collecting transformers==4.39.1
#   Downloading transformers-4.39.1-py3-none-any.whl (8.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 66.1 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.39.1) (3.13.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers==4.39.1) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.39.1) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.39.1) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.39.1) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.39.1) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.39.1) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers==4.39.1) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.39.1) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.39.1) (4.66.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.39.1) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.39.1) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.39.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.39.1) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.39.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.39.1) (2024.2.2)
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.38.2
#     Uninstalling transformers-4.38.2:
#       Successfully uninstalled transformers-4.38.2
# Successfully installed transformers-4.39.1
# Collecting accelerate==0.28.0
#   Downloading accelerate-0.28.0-py3-none-any.whl (290 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.1/290.1 kB 7.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.28.0) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.28.0) (24.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate==0.28.0) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate==0.28.0) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.28.0) (2.2.1+cu121)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate==0.28.0) (0.20.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.28.0) (0.4.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.28.0) (3.13.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.28.0) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.28.0) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.28.0) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.28.0) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.28.0) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.10.0->accelerate==0.28.0)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.10.0->accelerate==0.28.0)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.10.0->accelerate==0.28.0)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.10.0->accelerate==0.28.0)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.10.0->accelerate==0.28.0)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.10.0->accelerate==0.28.0)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.10.0->accelerate==0.28.0)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.10.0->accelerate==0.28.0)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.10.0->accelerate==0.28.0)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.10.0->accelerate==0.28.0)
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.10.0->accelerate==0.28.0)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.28.0) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->accelerate==0.28.0)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate==0.28.0) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate==0.28.0) (4.66.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate==0.28.0) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate==0.28.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate==0.28.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate==0.28.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate==0.28.0) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate==0.28.0) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, accelerate
# Successfully installed accelerate-0.28.0 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105
# Collecting evaluate
#   Downloading evaluate-0.4.1-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 2.7 MB/s eta 0:00:00
# Collecting datasets>=2.0.0 (from evaluate)
#   Downloading datasets-2.18.0-py3-none-any.whl (510 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 30.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from evaluate) (1.25.2)
# Collecting dill (from evaluate)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 17.6 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from evaluate) (4.66.2)
# Collecting xxhash (from evaluate)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 26.3 MB/s eta 0:00:00
# Collecting multiprocess (from evaluate)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 20.1 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2023.6.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.20.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from evaluate) (24.0)
# Collecting responses<0.19 (from evaluate)
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.13.4)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (0.6)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.9.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2024.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.16.0)
# Installing collected packages: xxhash, dill, responses, multiprocess, datasets, evaluate
# Successfully installed datasets-2.18.0 dill-0.3.8 evaluate-0.4.1 multiprocess-0.70.16 responses-0.18.0 xxhash-3.4.1
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.10/dist-packages (2.2.1+cu121)
# Requirement already satisfied: torch==2.2.1 in /usr/local/lib/python3.10/dist-packages (from torchaudio) (2.2.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->torchaudio) (3.13.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->torchaudio) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->torchaudio) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->torchaudio) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->torchaudio) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->torchaudio) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->torchaudio) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->torchaudio) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->torchaudio) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->torchaudio) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->torchaudio) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->torchaudio) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->torchaudio) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->torchaudio) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->torchaudio) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->torchaudio) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->torchaudio) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->torchaudio) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.2.1->torchaudio) (12.4.127)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.2.1->torchaudio) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.2.1->torchaudio) (1.3.0)
# Collecting flashlight-text
#   Downloading flashlight_text-0.0.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 22.4 MB/s eta 0:00:00
# Installing collected packages: flashlight-text
# Successfully installed flashlight-text-0.0.7
# Collecting jiwer
#   Downloading jiwer-3.0.3-py3-none-any.whl (21 kB)
# Requirement already satisfied: click<9.0.0,>=8.1.3 in /usr/local/lib/python3.10/dist-packages (from jiwer) (8.1.7)
# Collecting rapidfuzz<4,>=3 (from jiwer)
#   Downloading rapidfuzz-3.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 19.6 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, jiwer
# Successfully installed jiwer-3.0.3 rapidfuzz-3.8.1

# %% [markdown]
# # Useful Memory Clearing Tools

# %%
#del model
#del dsing_train
#del dsing_val
#del data_collator
#del asr_pipeline
#del training_args
#del trainer
#del wer_metric

# %%
import torch, gc
gc.collect()
torch.cuda.empty_cache()

# %% [markdown]
# # Basic Setup

# %%
import os
import sys
import time
import glob
import re
import json
import random
import tqdm

import torch
import torchaudio
import evaluate

import pandas as pd
import numpy as np
import IPython

from IPython.display import display, HTML, Audio

from datasets import load_dataset, load_metric, ClassLabel, DatasetDict

from torch.utils.data import DataLoader

from torchaudio.models.decoder import ctc_decoder
from torchaudio.models.decoder import download_pretrained_files

from transformers import Wav2Vec2CTCTokenizer
from transformers import Wav2Vec2FeatureExtractor
from transformers import pipeline

from transformers import TrainingArguments, Trainer
from transformers.utils import logging

# %%
#############################################
# Special Variables...
#############################################
root_folder = "/content/drive/MyDrive"

# Google Colab
#
tokens_file=f"{root_folder}/tokens.txt"
dataset_folder = "/dali_datasets"

# Local
#
# tokens_file="./tokens.txt"
# dataset_folder = "../sing_300x30x2/damp_dataset"
# root_folder = "./"


# read labels for all song utterances for DSING splits (test, dev (aka validation), train1 (aka train)
BATCH_SIZE=4
NUM_EPOCHS=10
MAX_SAMPLES=-1 #sample Utterances to use for training.  use -1 to get all the data.
CALC_HOURS=False

# %%
#
# Create Pipeline
#

# Simpler, smaller model.  Ou paper, the loss values fine tuned on DSing
# were comparable to the loss values with lv60-self.
#
#model_checkpoint="facebook/wav2vec2-base"
#
# When doing some early testing, I was able to easily overfit to a small
# set of songs which led me to believe that this set of weights likely
# will learn more easily on the sung dataset (DSING).  This specific
# model is used by the author (Ou) and meta fine tuned this model
# on 1000hrs of voice data.
#
model_checkpoint="facebook/wav2vec2-large-960h-lv60-self"

asr_pipeline = pipeline("automatic-speech-recognition", model=model_checkpoint, model_kwargs={"ctc_loss_reduction": 'mean'})
model = asr_pipeline.model

# Used in example here: https://huggingface.co/blog/fine-tune-wav2vec2-english
model.freeze_feature_encoder()

#
# Gradient Accumulation
# Used in example here: https://huggingface.co/blog/fine-tune-wav2vec2-english
# Per the code: By default, non-reentrant checkpoint stops recomputation as soon as it
#               has computed all needed Tensors.
#
model.gradient_checkpointing_enable(gradient_checkpointing_kwargs={"use_reentrant": False})

# Note: I want to use a beam search library that has been pre-trained on librispeech.  the pretrained beam search
#       has been created with all lowercase characters (i.e. phoneme settings, etc.).  I am changing the default
#       model tokenizer vocab settings to accept lower case inputs so i can use the decoder.  However, it will also
#       accept upper case, so this may also impact performance but only for inference.  (i.e. not sure where this
#       is normalized to .
asr_pipeline.tokenizer.do_lower_case = True

target_sampling_rate = asr_pipeline.feature_extractor.sampling_rate

# Count the number of trainable parameters in the model
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print("Trainable parameters:", trainable_params)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.61k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.26G [00:00<?, ?B/s]
# Some weights of the model checkpoint at facebook/wav2vec2-large-960h-lv60-self were not used when initializing Wav2Vec2ForCTC: ['wav2vec2.encoder.pos_conv_embed.conv.weight_g', 'wav2vec2.encoder.pos_conv_embed.conv.weight_v']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at facebook/wav2vec2-large-960h-lv60-self and are newly initialized: ['wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original0', 'wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original1', 'wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# tokenizer_config.json:   0%|          | 0.00/162 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/291 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/85.0 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/158 [00:00<?, ?B/s]
# Trainable parameters: 311261344

# %%
asr_pipeline.feature_extractor
# Out:
# Wav2Vec2FeatureExtractor {
#   "do_normalize": true,
#   "feature_extractor_type": "Wav2Vec2FeatureExtractor",
#   "feature_size": 1,
#   "padding_side": "right",
#   "padding_value": 0.0,
#   "return_attention_mask": true,
#   "sampling_rate": 16000
# }

# %%
asr_pipeline.tokenizer
# Out:
# Wav2Vec2CTCTokenizer(name_or_path='facebook/wav2vec2-large-960h-lv60-self', vocab_size=32, model_max_length=1000000000000000019884624838656, is_fast=False, padding_side='right', truncation_side='right', special_tokens={'bos_token': '<s>', 'eos_token': '</s>', 'unk_token': '<unk>', 'pad_token': '<pad>'}, clean_up_tokenization_spaces=True),  added_tokens_decoder={
# 	0: AddedToken("<pad>", rstrip=True, lstrip=True, single_word=False, normalized=False, special=False),
# 	1: AddedToken("<s>", rstrip=True, lstrip=True, single_word=False, normalized=False, special=False),
# 	2: AddedToken("</s>", rstrip=True, lstrip=True, single_word=False, normalized=False, special=False),
# 	3: AddedToken("<unk>", rstrip=True, lstrip=True, single_word=False, normalized=False, special=False),
# }

# %% [markdown]
# ## Decoders

# %%
files = download_pretrained_files("librispeech-4-gram")
# Found from Fairseq for Wav2Vec2 -
# https://github.com/facebookresearch/fairseq/blob/main/examples/wav2vec/config/finetuning/vox_960h_2_aws.yaml
# Note: I am not using the same lexicon file though...
# LM_WEIGHT = 2.0
# WORD_SCORE = 0
# SIL_SCORE = -1

LM_WEIGHT = 3.23
WORD_SCORE = -0.26
SIL_SCORE = 0

beam_search_decoder = ctc_decoder(
    lexicon=files.lexicon,
    tokens=tokens_file,
    lm=files.lm,
    nbest=1,
    beam_size=512, #per the paper by Ou
    lm_weight=LM_WEIGHT,
    word_score=WORD_SCORE,
    sil_score=SIL_SCORE,
    blank_token='<pad>',
    unk_word='<unk>'
)

greedy_decoder = ctc_decoder(
    lexicon=files.lexicon,
    tokens=tokens_file,
    lm=files.lm,
    nbest=1,
    beam_size=1,
    lm_weight=LM_WEIGHT,
    word_score=WORD_SCORE,
    sil_score=SIL_SCORE,
    blank_token='<pad>',
    unk_word='<unk>'
)
# Out:
# 100%|██████████| 4.97M/4.97M [00:00<00:00, 93.7MB/s]
# 100%|██████████| 57.0/57.0 [00:00<00:00, 196kB/s]
# 100%|██████████| 2.91G/2.91G [00:45<00:00, 68.5MB/s]

# %% [markdown]
# # Generate Hugginface Dataset Object from DAMP 300x30x2 dataset
#
# Reference: https://huggingface.co/docs/datasets/audio_load
#
# Other pre-processing is heavily inspired from: https://colab.research.google.com/drive/1nCC5Ci-81U5opK_VuXDiZlmcAuATreF2#scrollTo=RBDRAAYxRE6n

# %% [markdown]
# # Data Cleaning

# %%
def prepare_dataset(batch,tokenizer,feature_extractor):
    """
    Creating a new dataset with the map function to generate the
    keys below.  Padding will occur in the data collator on a per
    batch basis.

    Inputs (i.e. feature extractor):
    input_values   - tensor array for audio samples (shape=(n,) - where n is the number of audio samples)
    attention_mask - used for expressing where there are padded samples

    Outputs (i.e. tokenizer related)
    labels - tensor array for text output tokens (i.e. not transcript).  (shape=(m,) - where m is the number of character tokens)
    """
    chars_to_ignore_regex = '[\,\?\.\!\-\;\:\"]'
    batch["transcription"] = re.sub(chars_to_ignore_regex, '', batch["transcription"]).lower() + " "

    audio = batch["audio"]

    # batched output is "un-batched" to ensure mapping is correct

    # Feature Extractor manipulation
    #
    # this object will return a list of lists because the
    # transcriptions are not padded (i.e. as opposed to a
    # Tensor of tensors when using return_tensors='pt').
    # Padding is done per batch to optimize the size for inference and
    # training.
    #
    # data_collator is responsible for padding the data.
    inputs_values_pt = feature_extractor(audio["array"], sampling_rate=audio["sampling_rate"])

    #
    # use this condition because some Wav2Vec2 models require attention_masks
    # for better performance while others do not.
    #
    if "attention_mask" in inputs_values_pt:
        batch["attention_mask"] = inputs_values_pt.attention_mask

    batch["input_values"] = inputs_values_pt.input_values[0]
    batch["input_length"] = len(batch["input_values"])

    # Tokenizer manipulation
    #
    # this object will return a list of lists because the
    # transcriptions are not padded (i.e. as opposed to a
    # Tensor of tensors when using return_tensors='pt').
    # Padding is done per batch to optimize the size for inference and
    # training.
    #
    # data_collator is responsible for padding the data.
    labels_pt = tokenizer(batch["transcription"])
    batch["labels"] = labels_pt['input_ids']

    return batch

# %%
from dataclasses import dataclass
from typing import Any, Dict, List, Optional, Union

@dataclass
class DataCollatorCTCWithPadding:
    """
    Data collator that will dynamically pad the already tokenized inputs received.
    Args:
        processor (:class:`~transformers.Wav2Vec2Processor`)
            The processor used for proccessing the data.
        padding (:obj:`bool`, :obj:`str` or :class:`~transformers.tokenization_utils_base.PaddingStrategy`, `optional`, defaults to :obj:`True`):
            Select a strategy to pad the returned sequences (according to the model's padding side and padding index)
            among:
            * :obj:`True` or :obj:`'longest'`: Pad to the longest sequence in the batch (or no padding if only a single
              sequence if provided).

            Other Options in the pad method that are NOT implemented for this class (i.e. I always want to pad to longest for the
            input and the labels)
            * (not implemented) :obj:`'max_length'`: Pad to a maximum length specified with the argument :obj:`max_length` or to the
              maximum acceptable input length for the model if that argument is not provided.
            * (not implemented) :obj:`False` or :obj:`'do_not_pad'` (default): No padding (i.e., can output a batch with sequences of
              different lengths).

    Reference Code here:
    https://huggingface.co/blog/fine-tune-wav2vec2-english


    Note: in the example referenced above, there were parameters for padding max length, etc.  I have created some logic
    in the prepare_dataset to support truncation of data for testing and benchmarking.  I do not think i need max_length
    options for collator at this time.

    """

    tokenizer: Wav2Vec2CTCTokenizer
    feature_extractor: Wav2Vec2FeatureExtractor
    padding: Union[bool, str] = "longest"

    def __call__(self, features: List[Dict[str, Union[List[int], torch.Tensor]]]) -> Dict[str, torch.Tensor]:

        # Features in this case is a list of batch size that contains DataSet objects from the train split
        # (including pretokenized labels). the output batch has been changed from a list back to a dictionary
        # with the respective data objects.
        #
        # Note for future self:
        # pad is being called from PreTrainedTokenizerBase.pad.  From docs:
        #      Pad a single encoded input or a batch of encoded inputs up to predefined length or to the max sequence length
        #      in the batch.
        #
        #    Padding side (left/right) padding token ids are defined at the tokenizer level (with `self.padding_side`,
        #    `self.pad_token_id` and `self.pad_token_type_id`).

        #    Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the
        #    text followed by a call to the `pad` method to get a padded encoding.
        #
        #         <Tip>
        #
        #         If the `encoded_inputs` passed are dictionary of numpy arrays, PyTorch tensors or TensorFlow tensors, the
        #         result will use the same type unless you provide a different tensor type with `return_tensors`. In the case of
        #         PyTorch tensors, you will lose the specific device of your tensors however.
        #
        #         </Tip>

        # Audio Input Data (not tokenized)
        input_features = [{"input_values": feature["input_values"]} for feature in features]

        # batch is a dictionary-like type.
        batch = self.feature_extractor.pad(
            input_features,
            padding=self.padding,
            return_tensors="pt",
        )

        # Tokenized Transcript Labels (character level tokens)
        label_features = [{"input_ids": feature["labels"]} for feature in features]
        labels_batch = self.tokenizer.pad(
            label_features,
            padding=self.padding,
            return_tensors="pt",
        )

        # replace padding with -100 to ignore loss correctly
        batch["labels"] = labels_batch["input_ids"].masked_fill(labels_batch.attention_mask.ne(1), -100)

        return batch

# %%
wer_metric = evaluate.load("wer")

def compute_metrics_dummy(eval_pred):
    return {'wer':1.0}


def compute_metrics(eval_pred,kind='beam',compute=True):
    """
    Calculates WER for a batch of logits and their labels.

    eval_pred - tuple (logit output from the model, token labels from dataset)
    kind - can compare between beam search and greedy search.  both using kenlm

    compute - bool - for training this will compute WER every time its logged.
                     this is nice for understanding if the training is working.
                     for evaluation, this is set to false so compute is run after
                     all batches are processed.

    output is the WER computed from the batch.  if the model is run multiple times, the
    batch WERs are aggregated.

    Note: add_batch and then doing compute will clear the previously cached batch results.
    """
    logits, labels = eval_pred
    #print(f"Logit Type: {type(logits)}")

    # In some scenarios, the input the compute_metrics is a tensor.
    if type(logits) is np.ndarray:
        logits = torch.Tensor(logits)
    else:
        # copy this tensor for computing things...
        logits = logits.clone().detach().requires_grad_(False)
    #print(f"Changing Logit Type to: {type(logits)}")
    #print(f"{logits.shape}")

    if kind=='beam':
        # Creates a list of lists that are of size [batch_size,emissions,vocab_size]
        #
        # Where output[0][0] gives you the CTCHypothesis object.
        #
        # Extract transcript from output[0][0].words (i.e. list of words).
        # May need to join depending on objective.
        #
        predictions = beam_search_decoder(logits)
    elif kind=='greedy':
        # Creates a list of lists that are of size [batch_size,1]
        #
        # Where output[0][0] gives you the CTCHypothesis object.
        #
        # Extract transcript from output[0][0].words (i.e. list of words).
        # May need to join depending on objective.
        #
        predictions = greedy_decoder(logits)
    else:
        print(f"Error passing in decoder kind: {kind}")
        sys.exit()

    ref = asr_pipeline.tokenizer.batch_decode(labels)
    pred = [" ".join(prediction[0].words) for prediction in predictions]

    wer_metric.add_batch(predictions=pred, references=ref)

    if compute:
        return {"wer":wer_metric.compute()}

    return None
# Out:
# Downloading builder script:   0%|          | 0.00/4.49k [00:00<?, ?B/s]

# %% [markdown]
# # Load Dataset

# %%
data_collator = DataCollatorCTCWithPadding(
    tokenizer=asr_pipeline.tokenizer,
    feature_extractor=asr_pipeline.feature_extractor,
)

#
# Only read in MAX_SAMPLES samples that is used to
# get the WER.  This appears to give good performance in the paper (after 10 epochs)
# This has not been shuffled though so it is problematic distribution-wise.
#
#dsing_train = load_dataset("audiofolder", data_dir=dataset_folder, split=f'train[:{str(MAX_SAMPLES)}]')
#for DALI Dataset
dsing_train = load_dataset("audiofolder", data_dir=dataset_folder, split=f'test[1000:]')
if CALC_HOURS:
    arr_lens = [len(d['array']) for d in dsing_train['audio']]
    print(f"Total Hours of Training Data: {np.sum(arr_lens)/ target_sampling_rate / 3600:.2f}")

#dsing_train = dsing_train.to_iterable_dataset()
dsing_train = dsing_train.with_format('torch')
# make changes to dataset object to prepare for Wav2Vec2 model
dsing_train = dsing_train.map(
    prepare_dataset,
    remove_columns=["audio","transcription"],
    fn_kwargs={'tokenizer':asr_pipeline.tokenizer, 'feature_extractor':asr_pipeline.feature_extractor}
)

#
# Reading all of validation.  However, this takes about a minute to run,
# so only doing this a few times during each epoch.
#
dsing_val = load_dataset("audiofolder", data_dir="/damp_dataset", split='validation')
#dsing_val = dsing_val.to_iterable_dataset()
dsing_val = dsing_val.with_format('torch')
#
# make changes to dataset object to prepare for Wav2Vec2ForCTC model
#
dsing_val = dsing_val.map(
    prepare_dataset,
    remove_columns=["audio","transcription"],
    fn_kwargs={'tokenizer':asr_pipeline.tokenizer, 'feature_extractor':asr_pipeline.feature_extractor}
)
# Out:
# Resolving data files:   0%|          | 0/10187 [00:00<?, ?it/s]
# Map:   0%|          | 0/9186 [00:00<?, ? examples/s]
# Resolving data files:   0%|          | 0/10187 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-ad67419bc45a> in <cell line: 31>()
#      29 # so only doing this a few times during each epoch.
#      30 #
# ---> 31 dsing_val = load_dataset("audiofolder", data_dir=dataset_folder, split='validation')
#      32 #dsing_val = dsing_val.to_iterable_dataset()
#      33 dsing_val = dsing_val.with_format('torch')
#
# /usr/local/lib/python3.10/dist-packages/datasets/load.py in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, ignore_verifications, keep_in_memory, save_infos, revision, token, use_auth_token, task, streaming, num_proc, storage_options, trust_remote_code, **config_kwargs)
#    2593         keep_in_memory if keep_in_memory is not None else is_small_dataset(builder_instance.info.dataset_size)
#    2594     )
# -> 2595     ds = builder_instance.as_dataset(split=split, verification_mode=verification_mode, in_memory=keep_in_memory)
#    2596     # Rename and cast features to match task schema
#    2597     if task is not None:
#
# /usr/local/lib/python3.10/dist-packages/datasets/builder.py in as_dataset(self, split, run_post_process, verification_mode, ignore_verifications, in_memory)
#    1242
#    1243         # Create a dataset for each of the given splits
# -> 1244         datasets = map_nested(
#    1245             partial(
#    1246                 self._build_single_dataset,
#
# /usr/local/lib/python3.10/dist-packages/datasets/utils/py_utils.py in map_nested(function, data_struct, dict_only, map_list, map_tuple, map_numpy, num_proc, parallel_min_length, types, disable_tqdm, desc)
#     455     # Singleton
#     456     if not isinstance(data_struct, dict) and not isinstance(data_struct, types):
# --> 457         return function(data_struct)
#     458
#     459     iterable = list(data_struct.values()) if isinstance(data_struct, dict) else data_struct
#
# /usr/local/lib/python3.10/dist-packages/datasets/builder.py in _build_single_dataset(self, split, run_post_process, verification_mode, in_memory)
#    1272
#    1273         # Build base dataset
# -> 1274         ds = self._as_dataset(
#    1275             split=split,
#    1276             in_memory=in_memory,
#
# /usr/local/lib/python3.10/dist-packages/datasets/builder.py in _as_dataset(self, split, in_memory)
#    1346         if self._check_legacy_cache():
#    1347             dataset_name = self.name
# -> 1348         dataset_kwargs = ArrowReader(cache_dir, self.info).read(
#    1349             name=dataset_name,
#    1350             instructions=split,
#
# /usr/local/lib/python3.10/dist-packages/datasets/arrow_reader.py in read(self, name, instructions, split_infos, in_memory)
#     249         """
#     250
# --> 251         files = self.get_file_instructions(name, instructions, split_infos)
#     252         if not files:
#     253             msg = f'Instruction "{instructions}" corresponds to no data!'
#
# /usr/local/lib/python3.10/dist-packages/datasets/arrow_reader.py in get_file_instructions(self, name, instruction, split_infos)
#     222     def get_file_instructions(self, name, instruction, split_infos):
#     223         """Return list of dict {'filename': str, 'skip': int, 'take': int}"""
# --> 224         file_instructions = make_file_instructions(
#     225             name, split_infos, instruction, filetype_suffix=self._filetype_suffix, prefix_path=self._path
#     226         )
#
# /usr/local/lib/python3.10/dist-packages/datasets/arrow_reader.py in make_file_instructions(name, split_infos, instruction, filetype_suffix, prefix_path)
#     131         instruction = ReadInstruction.from_spec(instruction)
#     132     # Create the absolute instruction (per split)
# --> 133     absolute_instructions = instruction.to_absolute(name2len)
#     134
#     135     # For each split, return the files instruction (skip/take)
#
# /usr/local/lib/python3.10/dist-packages/datasets/arrow_reader.py in to_absolute(self, name2len)
#     659             list of _AbsoluteInstruction instances (corresponds to the + in spec).
#     660         """
# --> 661         return [_rel_to_abs_instr(rel_instr, name2len) for rel_instr in self._relative_instructions]
#
# /usr/local/lib/python3.10/dist-packages/datasets/arrow_reader.py in <listcomp>(.0)
#     659             list of _AbsoluteInstruction instances (corresponds to the + in spec).
#     660         """
# --> 661         return [_rel_to_abs_instr(rel_instr, name2len) for rel_instr in self._relative_instructions]
#
# /usr/local/lib/python3.10/dist-packages/datasets/arrow_reader.py in _rel_to_abs_instr(rel_instr, name2len)
#     476     split = rel_instr.splitname
#     477     if split not in name2len:
# --> 478         raise ValueError(f'Unknown split "{split}". Should be one of {list(name2len)}.')
#     479     num_examples = name2len[split]
#     480     from_ = rel_instr.from_
#
# ValueError: Unknown split "validation". Should be one of ['test'].

# %%
#
# Reading all of validation.  However, this takes about a minute to run,
# so only doing this a few times during each epoch.
#
dsing_val = load_dataset("audiofolder", data_dir="/damp_dataset", split='validation')
#dsing_val = dsing_val.to_iterable_dataset()
dsing_val = dsing_val.with_format('torch')
#
# make changes to dataset object to prepare for Wav2Vec2ForCTC model
#
dsing_val = dsing_val.map(
    prepare_dataset,
    remove_columns=["audio","transcription"],
    fn_kwargs={'tokenizer':asr_pipeline.tokenizer, 'feature_extractor':asr_pipeline.feature_extractor}
)
# Out:
# Resolving data files:   0%|          | 0/8608 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/485 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/483 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Map:   0%|          | 0/482 [00:00<?, ? examples/s]

# %% [markdown]
# # Create Training Objects

# %%
#logging.set_verbosity_info()
#logger = logging.get_logger("transformers")
#logger.warning("INFO")

training_args = TrainingArguments(
    output_dir=f"/test_trainer_dali",
    overwrite_output_dir = True,
    # Cannot use num_train_epochs because of the lazy loading
    # that IterDatasets require.  They do not actullay know
    # prior to loading how many items are in the dataset
    # so max_steps helps manage that.
    num_train_epochs=NUM_EPOCHS,
    # typical setup is MAX_SAMPLES / BATCH_SIZE * NUM_EPOCHS
    #max_steps=8605 / BATCH_SIZE * NUM_EPOCHS,
    #max_steps=20000,
    # gradient_checkpointing
    # the trade off is  O(sqrt(n)) savings
    # with implemented memory-wise, at the
    # cost of performing one additional
    # forward pass.
    gradient_checkpointing=True,
    gradient_checkpointing_kwargs={"use_reentrant": False},
    gradient_accumulation_steps=1,
    #use_cpu=True,
    fp16=True,                      # use when we are doing the GPU based training
    fp16_full_eval=True,           # use cpu with eval to keep memory footprint low on all GPUs (T4, A100, V100)
    #resume_from_checkpoint=True,
    per_device_train_batch_size=BATCH_SIZE,
    per_device_eval_batch_size=BATCH_SIZE,
    evaluation_strategy="steps",
    eval_steps=500,
    logging_dir=f"{root_folder}/logs",
    #optim="adamw_torch",
    lr_scheduler_type='reduce_lr_on_plateau',
    # cooldown is a number of steps before attempting to lower the
    # learning rate again.
    lr_scheduler_kwargs={"mode":'min',"factor":0.9,"threshold":0.0025},
    learning_rate=1e-5,              # Based on Ou Paper
    #weight_decay=0.005,
    #warmup_steps=1000,
    save_strategy='steps',
    save_steps=500,
    metric_for_best_model='loss',
    save_total_limit=2,
    report_to='tensorboard',
    logging_strategy='steps',
    logging_steps=100,
    #load_best_model_at_end=True,
    #seed=42,
)

# %%
from transformers import TrainerCallback

class MyCallback(TrainerCallback):
    "A callback that prints a message at the beginning of training"

    def on_train_begin(self, args, state, control, **kwargs):
        print("Starting training")

trainer = Trainer(
    model=model,
    args=training_args,
    data_collator=data_collator,
    train_dataset=dsing_train,
    eval_dataset=dsing_val,
    compute_metrics=compute_metrics_dummy,
    tokenizer=asr_pipeline.feature_extractor,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/accelerate/accelerator.py:432: FutureWarning: Passing the following arguments to `Accelerator` is deprecated and will be removed in version 1.0 of Accelerate: dict_keys(['dispatch_batches', 'split_batches', 'even_batches', 'use_seedable_sampler']). Please pass an `accelerate.DataLoaderConfiguration` instead:
# dataloader_config = DataLoaderConfiguration(dispatch_batches=None, split_batches=False, even_batches=True, use_seedable_sampler=True)
#   warnings.warn(

# %%
start = time.time()
trainer.train()
finish = time.time()
print(f"Finished in {(finish-start)/60} minutes.")
# Out:
#     <div>
#
#       <progress value='22970' max='22970' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [22970/22970 1:33:22, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Wer</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>2.638000</td>
#       <td>0.761607</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>2.478500</td>
#       <td>0.742129</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>2.407700</td>
#       <td>0.727242</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>2.336000</td>
#       <td>0.734514</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>2.312700</td>
#       <td>0.717645</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>2.245800</td>
#       <td>0.726836</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>2.301300</td>
#       <td>0.716887</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>2.178700</td>
#       <td>0.714619</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>2.229500</td>
#       <td>0.710752</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>2.145800</td>
#       <td>0.714438</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>2.103800</td>
#       <td>0.719079</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>2.092700</td>
#       <td>0.719706</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>2.112500</td>
#       <td>0.697636</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>2.151500</td>
#       <td>0.723745</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>2.113700</td>
#       <td>0.699949</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>2.017600</td>
#       <td>0.709782</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>1.996600</td>
#       <td>0.714242</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>2.103100</td>
#       <td>0.696356</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>9500</td>
#       <td>1.965200</td>
#       <td>0.694192</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>2.022300</td>
#       <td>0.701185</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>10500</td>
#       <td>1.936100</td>
#       <td>0.700684</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>2.008900</td>
#       <td>0.685973</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>11500</td>
#       <td>1.907900</td>
#       <td>0.695741</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>1.930500</td>
#       <td>0.691069</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>12500</td>
#       <td>1.890900</td>
#       <td>0.689668</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>13000</td>
#       <td>1.921700</td>
#       <td>0.684214</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>13500</td>
#       <td>1.851300</td>
#       <td>0.690310</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>14000</td>
#       <td>1.877300</td>
#       <td>0.691823</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>14500</td>
#       <td>1.943500</td>
#       <td>0.672823</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>15000</td>
#       <td>1.833000</td>
#       <td>0.679113</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>15500</td>
#       <td>1.852800</td>
#       <td>0.669041</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>16000</td>
#       <td>1.868600</td>
#       <td>0.683669</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>16500</td>
#       <td>1.813700</td>
#       <td>0.695376</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>17000</td>
#       <td>1.823200</td>
#       <td>0.692727</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>17500</td>
#       <td>1.839900</td>
#       <td>0.688108</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>18000</td>
#       <td>1.764900</td>
#       <td>0.690778</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>18500</td>
#       <td>1.873000</td>
#       <td>0.684383</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>19000</td>
#       <td>1.798000</td>
#       <td>0.687844</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>19500</td>
#       <td>1.689700</td>
#       <td>0.683242</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>20000</td>
#       <td>1.740800</td>
#       <td>0.684903</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>20500</td>
#       <td>1.734500</td>
#       <td>0.693901</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>21000</td>
#       <td>1.812200</td>
#       <td>0.679921</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>21500</td>
#       <td>1.703000</td>
#       <td>0.678071</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>22000</td>
#       <td>1.760700</td>
#       <td>0.667403</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>22500</td>
#       <td>1.782200</td>
#       <td>0.670156</td>
#       <td>1.000000</td>
#     </tr>
#   </tbody>
# </table><p>
# Finished in 93.42693453232447 minutes.

# %%
# %load_ext tensorboard
# %tensorboard --logdir "/content/drive/MyDrive/logs"
